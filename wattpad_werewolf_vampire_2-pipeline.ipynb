# %% [markdown]
# # Werewolf and vampire

# %%
import numpy as np
import pandas as pd
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.corpus import wordnet as wn
from sklearn.decomposition import LatentDirichletAllocation as LDA
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

# %% [markdown]
# ## Loading data

# %% [markdown]
# ### Stories

# %%
stories_df = pd.read_csv('data/out/werewolf_vampire_stories.csv')

# %%
stories_df.head()
# Out:
#    story_id  chapter_id  chapter_index  \
# 0    157305     1100896              0
# 1    157305     1108308              1
# 2    157305     1131027              2
# 3    157305     1157067              3
# 4    157305     1160601              4
#
#                                         chapter_text
# 0  'I packed whilst you were at school' she said ...
# 1  'Ladies and Gentlemen, this is your captain sp...
# 2  My father was still frowning but he seemed to ...
# 3  Bloody girl, why did she have to turn up...she...
# 4  Sam x I blushed and looked down... “Umm...well...

# %%
stories_df.shape
# Out:
# (23978, 4)

# %%
stories_df.story_id.nunique()
# Out:
# 5869

# %% [markdown]
# ## Processing data

# %% [markdown]
# ### Data

# %%
data = stories_df.chapter_text.values

# %%
len(data)
# Out:
# 23978

# %%
data = [d for d in data if d is not np.nan]

# %%
len(data)
# Out:
# 23972

# %%
# DELETE CELL
data=data[:10]

# %%
# %%time

wordnet_word_synsets = {}
for d in data:
    for w in word_tokenize(d):
        if w not in wordnet_word_synsets:
            synsets = wn.synsets(w)
            if synsets:
                wordnet_word_synsets[w] = synsets
# Out:
# CPU times: user 4.07 s, sys: 120 ms, total: 4.19 s
# Wall time: 4.19 s

# %%
len(wordnet_word_synsets)
# Out:
# 2460

# %%
# %%time

data = [' '.join([w for w in word_tokenize(d) if w in wordnet_word_synsets]) for d in data]
# Out:
# CPU times: user 200 ms, sys: 8 ms, total: 208 ms
# Wall time: 205 ms

# %%
data = [d for d in data if d.strip()]

# %%
len(data)
# Out:
# 10

# %%
for d in data:
    for w in word_tokenize(d):
        if w not in wordnet_word_synsets:
            print(w)
# Out:
# .

# %% [markdown]
# ### Auxiliar functions

# %%
def get_topic(topic, feature_names, n_top_words):
    return [feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]

def get_topics(model, feature_names, n_top_words):
    topics = []
    for topic in model.components_:
        topics.append(get_topic(topic, feature_names, n_top_words))
    return topics

# %%
# def print_topics(topics):
#     for topic_idx, topic in enumerate(topics):
#         print("Topic #%d:" % (topic_idx + 1))
#         print(" ".join(topic))
#         print()

def print_topics(topics):
    for topic_idx, (similariy, topic, n_topics) in enumerate(topics):
        print("Topic #%d:" % (topic_idx + 1))
        print('SIMILARITY:', similariy, '. Discovered topics:', n_topics)
        print(" ".join(topic))
        print()

# %%
def two_words_similarity(w1, w2):
    similarities = [0]
    for syns1 in wordnet_word_synsets[w1]:
        for syns2 in wordnet_word_synsets[w2]:
            similarity = wn.wup_similarity(syns1, syns2) or 0
            similarities.append(similarity)
    return max(similarities)

def word_list_similarity(ws):
    similarities = []
    for w1 in ws:
        for w2 in ws:
            if w1 != w2:
                similarity = two_words_similarity(w1, w2)
                similarities.append(similarity)
    return np.mean(similarities)

# def topic_list_similarity(ts):
#     similarities = []
#     for t in ts:
#         similarity = word_list_similarity(t)
#         similarities.append(similarity)
#     return np.mean(similarities)

# %% [markdown]
# ### Parameters

# %%
# parameters = [{
#         'vect__max_df': (0.95, 1.0),
#         'vect__min_df': (2, 1),
#         'vect__max_features': (10, 100, 1000),
#         'vect__stop_words': ('english',),
#         'topext__n_topics': list(range(1, 201)) + [300, 400, 500],
#         'topext__learning_method': ('online', 'batch'),
#         'topext__learning_offset': (10., 20., 30., 40., 50.),
#     }, {
#         'vect__max_df': (0.95, 1.0),
#         'vect__min_df': (2, 1),
#         'vect__max_features': (10, 100, 1000),
#         'vect__stop_words': ('english',),
#         'topext__n_components': list(range(1, 201)) + [300, 400, 500],
#         'topext__alpha': (0, .1, .5, 1.),
#         'topext__l1_ratio': (0, .5, 1.),
#     }
# ]
# topic_extractors = [LDA, NMF]
# vectorizers = [CountVectorizer, TfidfVectorizer]
# pipeline_parameters = list(zip(vectorizers, topic_extractors, parameters))

# %%
parameters = {
    'vect__max_df': (0.95, 1.0),
    'vect__min_df': (2, 1),
    'vect__max_features': (10, 100, 1000),
    'vect__stop_words': ('english',),
    'topext__n_topics': list(range(1, 201)) + [300, 400, 500],
    'topext__learning_method': ('online', 'batch'),
    'topext__learning_offset': (10., 20., 30., 40., 50.),
}

# %%
# DELETE CELL
parameters = {
    'vect__max_features': (100, 1000),
    'vect__stop_words': ('english',),
    'topext__n_topics': [100, 200],
    'topext__learning_offset': (40., 50.),
}

# %% [markdown]
# ### Topic extraction

# %%
import warnings
warnings.filterwarnings('ignore') # ("error", "ignore", "always", "default", "module", "once")

# %%
N_TOP_WORDS = 20

# %%
data_samples = data
len(data_samples)
# Out:
# 10

# %%
# %%time

# best_estimators = []
# for vectorizer, topic_extractor, parameters in pipeline_parameters:
pipeline = Pipeline([
    ('vect', CountVectorizer()),
    ('topext', LDA()),
])
grid_search_cv = GridSearchCV(pipeline, parameters, n_jobs=1)
grid_search_cv.fit(data_samples)

feature_names = grid_search_cv.best_estimator_.steps[0][1].get_feature_names()
topext = grid_search_cv.best_estimator_.steps[1][1]

topics = get_topics(topext, feature_names, N_TOP_WORDS)
similarities = [(word_list_similarity(topic), topic, len(topics)) for topic in topics]
sorted(similarities, reverse=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-6f74fef391e5> in <module>()
#      14
#      15 topics = get_topics(topext, feature_names, N_TOP_WORDS)
# ---> 16 similarities = [(word_list_similarity(topic), topic, len(topics)) for topic in topics]
#      17 sorted(similarities, reverse=True)
#
# <ipython-input-30-6f74fef391e5> in <listcomp>(.0)
#      14
#      15 topics = get_topics(topext, feature_names, N_TOP_WORDS)
# ---> 16 similarities = [(word_list_similarity(topic), topic, len(topics)) for topic in topics]
#      17 sorted(similarities, reverse=True)
#
# <ipython-input-18-f799e27398ef> in word_list_similarity(ws)
#      12         for w2 in ws:
#      13             if w1 != w2:
# ---> 14                 similarity = two_words_similarity(w1, w2)
#      15                 similarities.append(similarity)
#      16     return np.mean(similarities)
#
# <ipython-input-18-f799e27398ef> in two_words_similarity(w1, w2)
#       2     similarities = [0]
#       3     for syns1 in wordnet_word_synsets[w1]:
# ----> 4         for syns2 in wordnet_word_synsets[w2]:
#       5             similarity = wn.wup_similarity(syns1, syns2) or 0
#       6             similarities.append(similarity)
#
# KeyError: 'frank'

# %%
for d in data:
    if 'frank' in d:
        print('OK')

# %%
wordnet_word_synsets
# Out:
# {'looked': [Synset('look.v.01'),
#   Synset('look.v.02'),
#   Synset('look.v.03'),
#   Synset('search.v.02'),
#   Synset('front.v.01'),
#   Synset('attend.v.02'),
#   Synset('look.v.07'),
#   Synset('expect.v.03'),
#   Synset('look.v.09'),
#   Synset('count.v.08')],
#  'ipod': [Synset('ipod.n.01')],
#  'tried': [Synset('try.v.01'),
#   Synset('test.v.01'),
#   Synset('judge.v.05'),
#   Synset('sample.v.01'),
#   Synset('hear.v.03'),
#   Synset('try.v.06'),
#   Synset('try.v.07'),
#   Synset('try.v.08'),
#   Synset('try_on.v.01'),
#   Synset('tested.s.01'),
#   Synset('tested.s.02')],
#  'trees': [Synset('tree.n.01'),
#   Synset('tree.n.02'),
#   Synset('tree.n.03'),
#   Synset('corner.v.02'),
#   Synset('tree.v.02'),
#   Synset('tree.v.03'),
#   Synset('tree.v.04')],
#  'small': [Synset('small.n.01'),
#   Synset('small.n.02'),
#   Synset('small.a.01'),
#   Synset('minor.s.10'),
#   Synset('little.s.03'),
#   Synset('small.s.04'),
#   Synset('humble.s.01'),
#   Synset('little.s.07'),
#   Synset('little.s.05'),
#   Synset('small.s.08'),
#   Synset('modest.s.02'),
#   Synset('belittled.s.01'),
#   Synset('small.r.01')],
#  'petting': [Synset('caressing.n.01'), Synset('pet.v.01'), Synset('pet.v.02')],
#  'Get': [Synset('get.n.01'),
#   Synset('get.v.01'),
#   Synset('become.v.01'),
#   Synset('get.v.03'),
#   Synset('receive.v.02'),
#   Synset('arrive.v.01'),
#   Synset('bring.v.04'),
#   Synset('experience.v.03'),
#   Synset('pay_back.v.02'),
#   Synset('have.v.17'),
#   Synset('induce.v.02'),
#   Synset('get.v.11'),
#   Synset('grow.v.08'),
#   Synset('contract.v.04'),
#   Synset('get.v.14'),
#   Synset('make.v.02'),
#   Synset('drive.v.11'),
#   Synset('catch.v.18'),
#   Synset('catch.v.07'),
#   Synset('get.v.19'),
#   Synset('get.v.20'),
#   Synset('get.v.21'),
#   Synset('get.v.22'),
#   Synset('catch.v.21'),
#   Synset('catch.v.22'),
#   Synset('get.v.25'),
#   Synset('scram.v.01'),
#   Synset('get.v.27'),
#   Synset('get.v.28'),
#   Synset('get.v.29'),
#   Synset('catch.v.24'),
#   Synset('draw.v.15'),
#   Synset('get.v.32'),
#   Synset('perplex.v.01'),
#   Synset('get_down.v.07'),
#   Synset('suffer.v.02'),
#   Synset('beget.v.01')],
#  'chipper': [Synset('chipper.s.01')],
#  'seeing': [Synset('visual_perception.n.01'),
#   Synset('eyesight.n.01'),
#   Synset('see.v.01'),
#   Synset('understand.v.02'),
#   Synset('witness.v.02'),
#   Synset('visualize.v.01'),
#   Synset('see.v.05'),
#   Synset('learn.v.02'),
#   Synset('watch.v.03'),
#   Synset('meet.v.01'),
#   Synset('determine.v.08'),
#   Synset('see.v.10'),
#   Synset('see.v.11'),
#   Synset('see.v.12'),
#   Synset('visit.v.01'),
#   Synset('attend.v.02'),
#   Synset('see.v.15'),
#   Synset('go_steady.v.01'),
#   Synset('see.v.17'),
#   Synset('see.v.18'),
#   Synset('see.v.19'),
#   Synset('examine.v.02'),
#   Synset('experience.v.01'),
#   Synset('see.v.22'),
#   Synset('see.v.23'),
#   Synset('interpret.v.01'),
#   Synset('seeing.s.01')],
#  'foot': [Synset('foot.n.01'),
#   Synset('foot.n.02'),
#   Synset('foot.n.03'),
#   Synset('animal_foot.n.01'),
#   Synset('foundation.n.03'),
#   Synset('foot.n.06'),
#   Synset('foot.n.07'),
#   Synset('foot.n.08'),
#   Synset('infantry.n.01'),
#   Synset('metrical_foot.n.01'),
#   Synset('foot.n.11'),
#   Synset('foot.v.01'),
#   Synset('foot.v.02'),
#   Synset('foot.v.03')],
#  'news': [Synset('news.n.01'),
#   Synset('news.n.02'),
#   Synset('news_program.n.01'),
#   Synset('news.n.04'),
#   Synset('newsworthiness.n.01')],
#  'brief': [Synset('brief.n.01'),
#   Synset('brief.n.02'),
#   Synset('brief.v.01'),
#   Synset('brief.s.01'),
#   Synset('brief.s.02'),
#   Synset('abbreviated.s.01')],
#  'rising': [Synset('rise.n.04'),
#   Synset('rebellion.n.02'),
#   Synset('rise.v.01'),
#   Synset('rise.v.02'),
#   Synset('arise.v.03'),
#   Synset('rise.v.04'),
#   Synset('surface.v.01'),
#   Synset('originate.v.01'),
#   Synset('ascend.v.08'),
#   Synset('wax.v.02'),
#   Synset('heighten.v.01'),
#   Synset('get_up.v.02'),
#   Synset('rise.v.11'),
#   Synset('rise.v.12'),
#   Synset('rise.v.13'),
#   Synset('rebel.v.01'),
#   Synset('rise.v.15'),
#   Synset('rise.v.16'),
#   Synset('resurrect.v.03'),
#   Synset('rising.a.01'),
#   Synset('acclivitous.s.01'),
#   Synset('emerging.s.01'),
#   Synset('rising.s.04')],
#  'idea': [Synset('idea.n.01'),
#   Synset('mind.n.06'),
#   Synset('idea.n.03'),
#   Synset('estimate.n.01'),
#   Synset('theme.n.03')],
#  'knew': [Synset('know.v.01'),
#   Synset('know.v.02'),
#   Synset('know.v.03'),
#   Synset('know.v.04'),
#   Synset('know.v.05'),
#   Synset('acknowledge.v.06'),
#   Synset('know.v.07'),
#   Synset('sleep_together.v.01'),
#   Synset('know.v.09'),
#   Synset('know.v.10'),
#   Synset('know.v.11')],
#  'god': [Synset('god.n.01'),
#   Synset('deity.n.01'),
#   Synset('god.n.03'),
#   Synset('idol.n.01')],
#  'blouse': [Synset('blouse.n.01')],
#  'ways': [Synset('ways.n.01'),
#   Synset('manner.n.01'),
#   Synset('means.n.01'),
#   Synset('direction.n.01'),
#   Synset('way.n.04'),
#   Synset('way.n.05'),
#   Synset('way.n.06'),
#   Synset('way.n.07'),
#   Synset('room.n.02'),
#   Synset('way.n.09'),
#   Synset('way.n.10'),
#   Synset('way.n.11'),
#   Synset('way.n.12')],
#  'gin': [Synset('gin.n.01'),
#   Synset('snare.n.05'),
#   Synset('cotton_gin.n.01'),
#   Synset('gin.n.04'),
#   Synset('gin.v.01'),
#   Synset('gin.v.02')],
#  'understand': [Synset('understand.v.01'),
#   Synset('understand.v.02'),
#   Synset('understand.v.03'),
#   Synset('understand.v.04'),
#   Synset('sympathize.v.02')],
#  'gave': [Synset('give.v.01'),
#   Synset('yield.v.01'),
#   Synset('give.v.03'),
#   Synset('give.v.04'),
#   Synset('give.v.05'),
#   Synset('hold.v.03'),
#   Synset('give.v.07'),
#   Synset('give.v.08'),
#   Synset('give.v.09'),
#   Synset('give.v.10'),
#   Synset('render.v.04'),
#   Synset('impart.v.01'),
#   Synset('establish.v.05'),
#   Synset('give.v.14'),
#   Synset('give.v.15'),
#   Synset('sacrifice.v.01'),
#   Synset('pass.v.05'),
#   Synset('give.v.18'),
#   Synset('give.v.19'),
#   Synset('give.v.20'),
#   Synset('give.v.21'),
#   Synset('grant.v.05'),
#   Synset('move_over.v.01'),
#   Synset('feed.v.02'),
#   Synset('contribute.v.02'),
#   Synset('collapse.v.01'),
#   Synset('give.v.27'),
#   Synset('give.v.28'),
#   Synset('give.v.29'),
#   Synset('afford.v.04'),
#   Synset('give.v.31'),
#   Synset('give.v.32'),
#   Synset('give.v.33'),
#   Synset('give.v.34'),
#   Synset('give.v.35'),
#   Synset('give.v.36'),
#   Synset('give.v.37'),
#   Synset('give.v.38'),
#   Synset('give.v.39'),
#   Synset('give.v.40'),
#   Synset('give.v.41'),
#   Synset('give.v.42'),
#   Synset('give.v.43'),
#   Synset('give.v.44')],
#  'seats': [Synset('seating.n.01'),
#   Synset('seat.n.01'),
#   Synset('buttocks.n.01'),
#   Synset('seat.n.03'),
#   Synset('seat.n.04'),
#   Synset('seat.n.05'),
#   Synset('seat.n.06'),
#   Synset('seat.n.07'),
#   Synset('seat.n.08'),
#   Synset('seat.n.09'),
#   Synset('seat.v.01'),
#   Synset('seat.v.02'),
#   Synset('induct.v.01'),
#   Synset('seat.v.04'),
#   Synset('seat.v.05'),
#   Synset('seat.v.06'),
#   Synset('seat.v.07')],
#  'follow': [Synset('follow.v.01'),
#   Synset('postdate.v.01'),
#   Synset('follow.v.03'),
#   Synset('follow.v.04'),
#   Synset('comply.v.01'),
#   Synset('follow.v.06'),
#   Synset('follow.v.07'),
#   Synset('follow.v.08'),
#   Synset('adopt.v.01'),
#   Synset('follow.v.10'),
#   Synset('take_after.v.02'),
#   Synset('trace.v.01'),
#   Synset('watch.v.02'),
#   Synset('succeed.v.02'),
#   Synset('play_along.v.02'),
#   Synset('keep_up.v.04'),
#   Synset('come.v.05'),
#   Synset('follow.v.18'),
#   Synset('follow.v.19'),
#   Synset('be.v.08'),
#   Synset('surveil.v.01'),
#   Synset('pursue.v.02'),
#   Synset('follow.v.23'),
#   Synset('stick_to.v.02')],
#  'results': [Synset('consequence.n.01'),
#   Synset('solution.n.02'),
#   Synset('result.n.03'),
#   Synset('resultant_role.n.01'),
#   Synset('result.v.01'),
#   Synset('leave.v.07'),
#   Synset('result.v.03')],
#  'spoken': [Synset('talk.v.02'),
#   Synset('talk.v.01'),
#   Synset('speak.v.03'),
#   Synset('address.v.02'),
#   Synset('speak.v.05'),
#   Synset('spoken.a.01')],
#  'motioned': [Synset('gesticulate.v.01')],
#  'energy': [Synset('energy.n.01'),
#   Synset('energy.n.02'),
#   Synset('energy.n.03'),
#   Synset('energy.n.04'),
#   Synset('energy.n.05'),
#   Synset('energy.n.06'),
#   Synset('department_of_energy.n.01')],
#  'photo': [Synset('photograph.n.01')],
#  'Huge': [Synset('huge.s.01')],
#  'exit': [Synset('exit.n.01'),
#   Synset('passing.n.02'),
#   Synset('exit.n.03'),
#   Synset('exit.v.01'),
#   Synset('exit.v.02'),
#   Synset('die.v.01')],
#  'doghouse': [Synset('kennel.n.01'), Synset('doghouse.n.02')],
#  'shy': [Synset('shy.n.01'),
#   Synset('shy.v.01'),
#   Synset('shy.v.02'),
#   Synset('diffident.a.02'),
#   Synset('shy.s.02'),
#   Synset('shy.s.03')],
#  'nine': [Synset('nine.n.01'),
#   Synset('baseball_club.n.01'),
#   Synset('nine-spot.n.01'),
#   Synset('nine.s.01')],
#  'known': [Synset('know.v.01'),
#   Synset('know.v.02'),
#   Synset('know.v.03'),
#   Synset('know.v.04'),
#   Synset('know.v.05'),
#   Synset('acknowledge.v.06'),
#   Synset('know.v.07'),
#   Synset('sleep_together.v.01'),
#   Synset('know.v.09'),
#   Synset('know.v.10'),
#   Synset('know.v.11'),
#   Synset('known.a.01')],
#  'replied': [Synset('answer.v.01')],
#  'Girl': [Synset('girl.n.01'),
#   Synset('female_child.n.01'),
#   Synset('daughter.n.01'),
#   Synset('girlfriend.n.02'),
#   Synset('girl.n.05')],
#  'magnetic': [Synset('magnetic.a.01'),
#   Synset('magnetic.a.02'),
#   Synset('magnetic.a.03'),
#   Synset('magnetic.a.04'),
#   Synset('charismatic.s.01')],
#  'genuinely': [Synset('truly.r.01'), Synset('authentically.r.01')],
#  'curly': [Synset('curly.a.01')],
#  'control': [Synset('control.n.01'),
#   Synset('control.n.02'),
#   Synset('control.n.03'),
#   Synset('control_condition.n.01'),
#   Synset('control.n.05'),
#   Synset('dominance.n.02'),
#   Synset('restraint.n.02'),
#   Synset('command.n.06'),
#   Synset('control.n.09'),
#   Synset('control.n.10'),
#   Synset('control.n.11'),
#   Synset('control.v.01'),
#   Synset('control.v.02'),
#   Synset('operate.v.03'),
#   Synset('manipulate.v.05'),
#   Synset('control.v.05'),
#   Synset('control.v.06'),
#   Synset('see.v.10'),
#   Synset('master.v.04')],
#  'school': [Synset('school.n.01'),
#   Synset('school.n.02'),
#   Synset('school.n.03'),
#   Synset('school.n.04'),
#   Synset('school.n.05'),
#   Synset('school.n.06'),
#   Synset('school.n.07'),
#   Synset('school.v.01'),
#   Synset('educate.v.03'),
#   Synset('school.v.03')],
#  'middle': [Synset('center.n.01'),
#   Synset('middle.n.02'),
#   Synset('middle.n.03'),
#   Synset('middle.n.04'),
#   Synset('middle.v.01'),
#   Synset('in-between.s.01'),
#   Synset('center.s.01'),
#   Synset('middle.a.03'),
#   Synset('middle.a.04')],
#  'meet': [Synset('meet.n.01'),
#   Synset('meet.v.01'),
#   Synset('meet.v.02'),
#   Synset('converge.v.01'),
#   Synset('meet.v.04'),
#   Synset('meet.v.05'),
#   Synset('meet.v.06'),
#   Synset('meet.v.07'),
#   Synset('meet.v.08'),
#   Synset('meet.v.09'),
#   Synset('meet.v.10'),
#   Synset('meet.v.11'),
#   Synset('suffer.v.10'),
#   Synset('touch.v.05'),
#   Synset('fitting.s.02')],
#  'adrenaline': [Synset('epinephrine.n.01')],
#  'sweetly': [Synset('sweetly.r.01')],
#  'hit': [Synset('hit.n.01'),
#   Synset('hit.n.02'),
#   Synset('hit.n.03'),
#   Synset('collision.n.01'),
#   Synset('hit.n.05'),
#   Synset('hit.n.06'),
#   Synset('hit.n.07'),
#   Synset('hit.v.01'),
#   Synset('hit.v.02'),
#   Synset('hit.v.03'),
#   Synset('reach.v.01'),
#   Synset('hit.v.05'),
#   Synset('shoot.v.01'),
#   Synset('stumble.v.03'),
#   Synset('score.v.01'),
#   Synset('hit.v.09'),
#   Synset('strike.v.04'),
#   Synset('murder.v.01'),
#   Synset('hit.v.12'),
#   Synset('reach.v.02'),
#   Synset('strike.v.10'),
#   Synset('hit.v.15'),
#   Synset('hit.v.16'),
#   Synset('hit.v.17')],
#  'bestowed': [Synset('confer.v.02'),
#   Synset('bestow.v.02'),
#   Synset('lend.v.01')],
#  'continued': [Synset('continue.v.01'),
#   Synset('continue.v.02'),
#   Synset('continue.v.03'),
#   Synset('proceed.v.02'),
#   Synset('retain.v.02'),
#   Synset('continue.v.06'),
#   Synset('continue.v.07'),
#   Synset('stay.v.04'),
#   Synset('cover.v.03'),
#   Synset('continue.v.10'),
#   Synset('continued.a.01')],
#  'new': [Synset('new.a.01'),
#   Synset('fresh.s.04'),
#   Synset('raw.s.12'),
#   Synset('new.s.04'),
#   Synset('new.s.05'),
#   Synset('new.a.06'),
#   Synset('newfangled.s.01'),
#   Synset('new.s.08'),
#   Synset('modern.s.05'),
#   Synset('new.s.10'),
#   Synset('new.s.11'),
#   Synset('newly.r.01')],
#  'talked': [Synset('talk.v.01'),
#   Synset('talk.v.02'),
#   Synset('speak.v.03'),
#   Synset('spill.v.05'),
#   Synset('spill_the_beans.v.01'),
#   Synset('lecture.v.01')],
#  'seat': [Synset('seat.n.01'),
#   Synset('buttocks.n.01'),
#   Synset('seat.n.03'),
#   Synset('seat.n.04'),
#   Synset('seat.n.05'),
#   Synset('seat.n.06'),
#   Synset('seat.n.07'),
#   Synset('seat.n.08'),
#   Synset('seat.n.09'),
#   Synset('seat.v.01'),
#   Synset('seat.v.02'),
#   Synset('induct.v.01'),
#   Synset('seat.v.04'),
#   Synset('seat.v.05'),
#   Synset('seat.v.06'),
#   Synset('seat.v.07')],
#  'thanks': [Synset('thanks.n.01'),
#   Synset('thanks.n.02'),
#   Synset('thank.v.01')],
#  'main': [Synset('main.n.01'),
#   Synset('main.n.02'),
#   Synset('chief.s.01'),
#   Synset('independent.a.03'),
#   Synset('main.s.03')],
#  'stop': [Synset('stop.n.01'),
#   Synset('stop.n.02'),
#   Synset('stop.n.03'),
#   Synset('arrest.n.02'),
#   Synset('stop.n.05'),
#   Synset('stop_consonant.n.01'),
#   Synset('period.n.07'),
#   Synset('stop.n.08'),
#   Synset('diaphragm.n.01'),
#   Synset('catch.n.06'),
#   Synset('blockage.n.02'),
#   Synset('stop.v.01'),
#   Synset('discontinue.v.01'),
#   Synset('stop.v.03'),
#   Synset('stop.v.04'),
#   Synset('stop.v.05'),
#   Synset('break.v.10'),
#   Synset('check.v.18'),
#   Synset('intercept.v.01'),
#   Synset('end.v.01'),
#   Synset('barricade.v.01'),
#   Synset('hold_on.v.02')],
#  'brought': [Synset('bring.v.01'),
#   Synset('bring.v.02'),
#   Synset('bring.v.03'),
#   Synset('bring.v.04'),
#   Synset('bring.v.05'),
#   Synset('bring.v.06'),
#   Synset('institute.v.02'),
#   Synset('lend.v.01'),
#   Synset('fetch.v.02'),
#   Synset('bring.v.10'),
#   Synset('bring.v.11')],
#  'posh': [Synset('classy.s.01')],
#  'York': [Synset('york.n.01')],
#  'exited': [Synset('exit.v.01'), Synset('exit.v.02'), Synset('die.v.01')],
#  '3': [Synset('three.n.01'), Synset('three.s.01')],
#  'mate': [Synset('mate.n.01'),
#   Synset('teammate.n.01'),
#   Synset('mate.n.03'),
#   Synset('spouse.n.01'),
#   Synset('match.n.04'),
#   Synset('mate.n.06'),
#   Synset('mate.n.07'),
#   Synset('mate.n.08'),
#   Synset('mate.n.09'),
#   Synset('checkmate.n.02'),
#   Synset('copulate.v.01'),
#   Synset('match.v.03'),
#   Synset('checkmate.v.01')],
#  'turn': [Synset('bend.n.01'),
#   Synset('turn.n.02'),
#   Synset('turn.n.03'),
#   Synset('turn.n.04'),
#   Synset('turning.n.04'),
#   Synset('turn.n.06'),
#   Synset('twist.n.13'),
#   Synset('go.n.01'),
#   Synset('turn.n.09'),
#   Synset('act.n.04'),
#   Synset('turn.n.11'),
#   Synset('turn.n.12'),
#   Synset('turn.v.01'),
#   Synset('change_state.v.01'),
#   Synset('become.v.02'),
#   Synset('turn.v.04'),
#   Synset('change_by_reversal.v.01'),
#   Synset('turn.v.06'),
#   Synset('turn.v.07'),
#   Synset('turn.v.08'),
#   Synset('turn.v.09'),
#   Synset('turn.v.10'),
#   Synset('turn.v.11'),
#   Synset('plow.v.01'),
#   Synset('turn.v.13'),
#   Synset('turn.v.14'),
#   Synset('twist.v.10'),
#   Synset('turn.v.16'),
#   Synset('turn.v.17'),
#   Synset('turn.v.18'),
#   Synset('turn.v.19'),
#   Synset('turn.v.20'),
#   Synset('flex.v.05'),
#   Synset('turn.v.22'),
#   Synset('turn.v.23'),
#   Synset('call_on.v.01'),
#   Synset('sour.v.01'),
#   Synset('turn.v.26')],
#  'softness': [Synset('softness.n.01'),
#   Synset('unfitness.n.01'),
#   Synset('balminess.n.01'),
#   Synset('softness.n.04'),
#   Synset('softness.n.05'),
#   Synset('softness.n.06'),
#   Synset('gentleness.n.02'),
#   Synset('indistinctness.n.01'),
#   Synset('effeminacy.n.01'),
#   Synset('softness.n.10')],
#  'career': [Synset('career.n.01'),
#   Synset('career.n.02'),
#   Synset('career.v.01')],
#  'BLOODY': [Synset('bloody.v.01'),
#   Synset('bloody.a.01'),
#   Synset('bally.s.01'),
#   Synset('bloody.r.01')],
#  'cancer': [Synset('cancer.n.01'),
#   Synset('cancer.n.02'),
#   Synset('cancer.n.03'),
#   Synset('cancer.n.04'),
#   Synset('cancer.n.05')],
#  'momma': [Synset('ma.n.01')],
#  'wish': [Synset('wish.n.01'),
#   Synset('wish.n.02'),
#   Synset('regard.n.03'),
#   Synset('wish.n.04'),
#   Synset('wish.v.01'),
#   Synset('wish.v.02'),
#   Synset('wish.v.03'),
#   Synset('wish.v.04'),
#   Synset('wish.v.05'),
#   Synset('wish.v.06')],
#  'Crystal': [Synset('crystal.n.01'),
#   Synset('crystal.n.02'),
#   Synset('crystal.n.03'),
#   Synset('quartz_glass.n.01'),
#   Synset('crystal.n.05'),
#   Synset('crystal.n.06')],
#  'TV': [Synset('television.n.01'), Synset('television_receiver.n.01')],
#  'meant': [Synset('mean.v.01'),
#   Synset('entail.v.01'),
#   Synset('mean.v.03'),
#   Synset('intend.v.01'),
#   Synset('mean.v.05'),
#   Synset('think_of.v.04'),
#   Synset('mean.v.07')],
#  'working': [Synset('working.n.01'),
#   Synset('work.v.01'),
#   Synset('work.v.02'),
#   Synset('work.v.03'),
#   Synset('function.v.01'),
#   Synset('work.v.05'),
#   Synset('exercise.v.03'),
#   Synset('make.v.36'),
#   Synset('work.v.08'),
#   Synset('work.v.09'),
#   Synset('work.v.10'),
#   Synset('bring.v.03'),
#   Synset('work.v.12'),
#   Synset('cultivate.v.02'),
#   Synset('work.v.14'),
#   Synset('influence.v.01'),
#   Synset('work.v.16'),
#   Synset('work.v.17'),
#   Synset('work.v.18'),
#   Synset('work.v.19'),
#   Synset('shape.v.02'),
#   Synset('work.v.21'),
#   Synset('knead.v.01'),
#   Synset('exploit.v.01'),
#   Synset('solve.v.01'),
#   Synset('ferment.v.03'),
#   Synset('sour.v.01'),
#   Synset('work.v.27'),
#   Synset('working.s.01'),
#   Synset('working.s.02'),
#   Synset('working.s.03'),
#   Synset('running.s.06'),
#   Synset('working.s.05')],
#  'shuttle': [Synset('shuttlecock.n.01'),
#   Synset('shuttle.n.02'),
#   Synset('shuttle.n.03'),
#   Synset('shuttle.v.01')],
#  'halt': [Synset('arrest.n.02'),
#   Synset('stop.n.01'),
#   Synset('freeze.n.03'),
#   Synset('halt.v.01'),
#   Synset('stop.v.01'),
#   Synset('stop.v.03'),
#   Synset('stem.v.03'),
#   Synset('crippled.s.01')],
#  'tall': [Synset('tall.n.01'),
#   Synset('tall.a.01'),
#   Synset('grandiloquent.s.01'),
#   Synset('tall.s.03'),
#   Synset('improbable.s.03')],
#  'happened': [Synset('happen.v.01'),
#   Synset('happen.v.02'),
#   Synset('happen.v.03'),
#   Synset('happen.v.04'),
#   Synset('find.v.01')],
#  'jam': [Synset('jam.n.01'),
#   Synset('fix.n.01'),
#   Synset('crush.n.02'),
#   Synset('jamming.n.01'),
#   Synset('throng.v.01'),
#   Synset('jam.v.02'),
#   Synset('jam.v.03'),
#   Synset('jam.v.04'),
#   Synset('jam.v.05'),
#   Synset('jam.v.06'),
#   Synset('obstruct.v.02')],
#  'sisterly': [Synset('sisterly.a.01')],
#  'sounding': [Synset('sounding.n.01'),
#   Synset('sounding.n.02'),
#   Synset('sound.v.01'),
#   Synset('sound.v.02'),
#   Synset('sound.v.03'),
#   Synset('sound.v.04'),
#   Synset('voice.v.02'),
#   Synset('sound.v.06'),
#   Synset('fathom.v.02'),
#   Synset('looking.s.01'),
#   Synset('sounding.s.02'),
#   Synset('sounding.s.03')],
#  'submitted': [Synset('submit.v.01'),
#   Synset('submit.v.02'),
#   Synset('submit.v.03'),
#   Synset('present.v.04'),
#   Synset('relegate.v.01'),
#   Synset('submit.v.06'),
#   Synset('take.v.19'),
#   Synset('put_in.v.05'),
#   Synset('render.v.06'),
#   Synset('resign.v.04')],
#  'it': [Synset('information_technology.n.01')],
#  'natural': [Synset('natural.n.01'),
#   Synset('natural.n.02'),
#   Synset('natural.n.03'),
#   Synset('natural.a.01'),
#   Synset('natural.a.02'),
#   Synset('natural.a.03'),
#   Synset('natural.s.04'),
#   Synset('natural.a.05'),
#   Synset('natural.s.06'),
#   Synset('natural.s.07'),
#   Synset('natural.s.08'),
#   Synset('natural.s.09'),
#   Synset('lifelike.s.02')],
#  'barrier': [Synset('barrier.n.01'),
#   Synset('barrier.n.02'),
#   Synset('barrier.n.03')],
#  'surrounded': [Synset('surround.v.01'),
#   Synset('smother.v.01'),
#   Synset('besiege.v.01'),
#   Synset('wall.v.01'),
#   Synset('surrounded.s.01')],
#  'showing': [Synset('screening.n.01'),
#   Synset('display.n.02'),
#   Synset('show.v.01'),
#   Synset('prove.v.02'),
#   Synset('testify.v.02'),
#   Synset('show.v.04'),
#   Synset('picture.v.02'),
#   Synset('express.v.01'),
#   Synset('indicate.v.02'),
#   Synset('show.v.08'),
#   Synset('read.v.08'),
#   Synset('show.v.10'),
#   Synset('usher.v.01'),
#   Synset('show.v.12')],
#  'prenatal': [Synset('prenatal.a.01')],
#  'heard': [Synset('hear.v.01'),
#   Synset('learn.v.02'),
#   Synset('hear.v.03'),
#   Synset('hear.v.04'),
#   Synset('listen.v.02'),
#   Synset('heard.s.01')],
#  'suit': [Synset('suit.n.01'),
#   Synset('lawsuit.n.01'),
#   Synset('suit.n.03'),
#   Synset('courtship.n.01'),
#   Synset('suit.n.05'),
#   Synset('suit.n.06'),
#   Synset('suit.v.01'),
#   Synset('suit.v.02'),
#   Synset('befit.v.01'),
#   Synset('become.v.04')],
#  'hurry': [Synset('hurry.n.01'),
#   Synset('haste.n.01'),
#   Synset('haste.n.02'),
#   Synset('travel_rapidly.v.01'),
#   Synset('rush.v.04'),
#   Synset('rush.v.03')],
#  'hate': [Synset('hate.n.01'), Synset('hate.v.01')],
#  'emotion': [Synset('emotion.n.01')],
#  'drain': [Synset('drain.n.01'),
#   Synset('drain.n.02'),
#   Synset('drain.n.03'),
#   Synset('drain.n.04'),
#   Synset('drain.v.01'),
#   Synset('drain.v.02'),
#   Synset('drain.v.03'),
#   Synset('enfeeble.v.01')],
#  'afraid': [Synset('afraid.a.01'),
#   Synset('afraid.s.02'),
#   Synset('afraid.s.03'),
#   Synset('afraid.s.04')],
#  'continuous': [Synset('continuous.a.01'), Synset('continuous.a.02')],
#  'buckle': [Synset('buckle.n.01'),
#   Synset('warp.n.02'),
#   Synset('buckle.v.01'),
#   Synset('buckle.v.02'),
#   Synset('heave.v.07')],
#  'innocently': [Synset('innocently.r.01'), Synset('innocently.r.02')],
#  'horn': [Synset('horn.n.01'),
#   Synset('horn.n.02'),
#   Synset('horn.n.03'),
#   Synset('horn.n.04'),
#   Synset('cornet.n.01'),
#   Synset('horn.n.06'),
#   Synset('horn.n.07'),
#   Synset('horn.n.08'),
#   Synset('horn.n.09'),
#   Synset('french_horn.n.01'),
#   Synset('automobile_horn.n.01'),
#   Synset('horn.v.01')],
#  'may': [Synset('may.n.01'), Synset('whitethorn.n.01')],
#  'isn': [Synset('international_relations_and_security_network.n.01')],
#  'GROWLED': [Synset('grumble.v.03')],
#  'letter': [Synset('letter.n.01'),
#   Synset('letter.n.02'),
#   Synset('letter.n.03'),
#   Synset('letter.n.04'),
#   Synset('letter.n.05'),
#   Synset('letter.v.01'),
#   Synset('letter.v.02'),
#   Synset('letter.v.03')],
#  'don': [Synset('don.n.01'),
#   Synset('preceptor.n.01'),
#   Synset('don.n.03'),
#   Synset('don.n.04'),
#   Synset('don.n.05'),
#   Synset('don.n.06'),
#   Synset('wear.v.09')],
#  'having': [Synset('have.v.01'),
#   Synset('have.v.02'),
#   Synset('experience.v.03'),
#   Synset('own.v.01'),
#   Synset('get.v.03'),
#   Synset('consume.v.02'),
#   Synset('have.v.07'),
#   Synset('hold.v.03'),
#   Synset('have.v.09'),
#   Synset('have.v.10'),
#   Synset('have.v.11'),
#   Synset('have.v.12'),
#   Synset('induce.v.02'),
#   Synset('accept.v.02'),
#   Synset('receive.v.01'),
#   Synset('suffer.v.02'),
#   Synset('have.v.17'),
#   Synset('give_birth.v.01'),
#   Synset('take.v.35')],
#  'feet': [Synset('foot.n.01'),
#   Synset('foot.n.02'),
#   Synset('foot.n.03'),
#   Synset('animal_foot.n.01'),
#   Synset('foundation.n.03'),
#   Synset('foot.n.06'),
#   Synset('foot.n.07'),
#   Synset('foot.n.08'),
#   Synset('infantry.n.01'),
#   Synset('metrical_foot.n.01'),
#   Synset('foot.n.11')],
#  'DNA': [Synset('deoxyribonucleic_acid.n.01')],
#  'wished': [Synset('wish.v.01'),
#   Synset('wish.v.02'),
#   Synset('wish.v.03'),
#   Synset('wish.v.04'),
#   Synset('wish.v.05'),
#   Synset('wish.v.06')],
#  'moving': [Synset('travel.v.01'),
#   Synset('move.v.02'),
#   Synset('move.v.03'),
#   Synset('move.v.04'),
#   Synset('go.v.02'),
#   Synset('be_active.v.01'),
#   Synset('move.v.07'),
#   Synset('act.v.01'),
#   Synset('affect.v.05'),
#   Synset('motivate.v.01'),
#   Synset('move.v.11'),
#   Synset('move.v.12'),
#   Synset('move.v.13'),
#   Synset('move.v.14'),
#   Synset('move.v.15'),
#   Synset('move.v.16'),
#   Synset('moving.a.01'),
#   Synset('moving.a.02'),
#   Synset('moving.a.03')],
#  'little': [Synset('little.n.01'),
#   Synset('small.a.01'),
#   Synset('little.a.02'),
#   Synset('little.s.03'),
#   Synset('fiddling.s.01'),
#   Synset('little.s.05'),
#   Synset('short.a.03'),
#   Synset('little.s.07'),
#   Synset('little.s.08'),
#   Synset('little.r.01')],
#  'Gods': [Synset('god.n.01'),
#   Synset('deity.n.01'),
#   Synset('god.n.03'),
#   Synset('idol.n.01')],
#  'clog': [Synset('clog.n.01'),
#   Synset('clog.n.02'),
#   Synset('clog_dance.n.01'),
#   Synset('clog.v.01'),
#   Synset('clog.v.02'),
#   Synset('clog.v.03'),
#   Synset('clog.v.04'),
#   Synset('clog.v.05'),
#   Synset('clog.v.06')],
#  'court': [Synset('court.n.01'),
#   Synset('court.n.02'),
#   Synset('court.n.03'),
#   Synset('court.n.04'),
#   Synset('court.n.05'),
#   Synset('court.n.06'),
#   Synset('motor_hotel.n.01'),
#   Synset('court.n.08'),
#   Synset('court.n.09'),
#   Synset('court.n.10'),
#   Synset('court.n.11'),
#   Synset('woo.v.02'),
#   Synset('woo.v.01'),
#   Synset('court.v.03')],
#  'pack': [Synset('battalion.n.02'),
#   Synset('pack.n.02'),
#   Synset('pack.n.03'),
#   Synset('gang.n.01'),
#   Synset('clique.n.01'),
#   Synset('pack.n.06'),
#   Synset('pack.n.07'),
#   Synset('pack.n.08'),
#   Synset('pack.n.09'),
#   Synset('pack.v.01'),
#   Synset('pack.v.02'),
#   Synset('pack.v.03'),
#   Synset('pack.v.04'),
#   Synset('pack.v.05'),
#   Synset('carry.v.02'),
#   Synset('throng.v.01'),
#   Synset('backpack.v.01'),
#   Synset('tamp_down.v.01'),
#   Synset('pack.v.10'),
#   Synset('compact.v.01'),
#   Synset('pack.v.12'),
#   Synset('pack.v.13')],
#  'serious': [Synset('serious.a.01'),
#   Synset('serious.s.02'),
#   Synset('dangerous.s.02'),
#   Synset('good.s.16'),
#   Synset('unplayful.a.01'),
#   Synset('serious.s.06')],
#  'beneath': [Synset('below.r.01')],
#  'substitute': [Synset('substitute.n.01'),
#   Synset('substitute.n.02'),
#   Synset('stand-in.n.01'),
#   Synset('substitute.v.01'),
#   Synset('substitute.v.02'),
#   Synset('substitute.v.03'),
#   Synset('utility.s.02'),
#   Synset('alternate.s.02'),
#   Synset('ersatz.s.01')],
#  'Not': [Synset('not.r.01')],
#  'old-fashioned': [Synset('antique.s.02')],
#  'extreme': [Synset('extreme.n.01'),
#   Synset('extreme_point.n.01'),
#   Synset('extreme.s.01'),
#   Synset('extreme.s.02'),
#   Synset('extreme.s.03'),
#   Synset('extreme.s.04')],
#  'eternity': [Synset('eternity.n.01'),
#   Synset('eternity.n.02'),
#   Synset('eternity.n.03')],
#  'steer': [Synset('tip.n.03'),
#   Synset('bullock.n.02'),
#   Synset('steer.v.01'),
#   Synset('steer.v.02'),
#   Synset('guide.v.03')],
#  'side': [Synset('side.n.01'),
#   Synset('side.n.02'),
#   Synset('side.n.03'),
#   Synset('side.n.04'),
#   Synset('side.n.05'),
#   Synset('side.n.06'),
#   Synset('side.n.07'),
#   Synset('side.n.08'),
#   Synset('side.n.09'),
#   Synset('side.n.10'),
#   Synset('slope.n.01'),
#   Synset('english.n.04'),
#   Synset('side.v.01'),
#   Synset('side.a.01')],
#  'promise': [Synset('promise.n.01'),
#   Synset('promise.n.02'),
#   Synset('promise.v.01'),
#   Synset('promise.v.02'),
#   Synset('predict.v.01'),
#   Synset('promise.v.04')],
#  'instead': [Synset('alternatively.r.01'), Synset('rather.r.01')],
#  'watched': [Synset('watch.v.01'),
#   Synset('watch.v.02'),
#   Synset('watch.v.03'),
#   Synset('watch.v.04'),
#   Synset('watch.v.05'),
#   Synset('watch.v.06'),
#   Synset('determine.v.08')],
#  'forth': [Synset('forth.n.01'),
#   Synset('away.r.01'),
#   Synset('forth.r.02'),
#   Synset('forth.r.03')],
#  'Assistant': [Synset('assistant.n.01'), Synset('adjunct.s.02')],
#  'crooked': [Synset('crook.v.01'),
#   Synset('crooked.a.01'),
#   Synset('crooked.a.02'),
#   Synset('asymmetrical.s.02'),
#   Synset('hunched.s.01')],
#  'bluest': [Synset('blue.s.01'),
#   Synset('blue.s.02'),
#   Synset('gloomy.s.02'),
#   Synset('blasphemous.s.02'),
#   Synset('blue.s.05'),
#   Synset('aristocratic.s.01'),
#   Synset('blue.s.07'),
#   Synset('blue.s.08')],
#  'couple': [Synset('couple.n.01'),
#   Synset('couple.n.02'),
#   Synset('couple.n.03'),
#   Synset('couple.n.04'),
#   Synset('couple.n.05'),
#   Synset('match.v.03'),
#   Synset('couple.v.02'),
#   Synset('pair.v.01'),
#   Synset('copulate.v.01')],
#  'always': [Synset('always.r.01'),
#   Synset('constantly.r.01'),
#   Synset('constantly.r.02'),
#   Synset('always.r.04'),
#   Synset('always.r.05')],
#  'idiots': [Synset('idiot.n.01')],
#  'stepped': [Synset('step.v.01'),
#   Synset('step.v.02'),
#   Synset('step.v.03'),
#   Synset('mistreat.v.01'),
#   Synset('step.v.05'),
#   Synset('step.v.06'),
#   Synset('step.v.07'),
#   Synset('step.v.08'),
#   Synset('pace.v.03'),
#   Synset('step.v.10')],
#  'walking': [Synset('walk.n.01'),
#   Synset('walk.v.01'),
#   Synset('walk.v.02'),
#   Synset('walk.v.03'),
#   Synset('walk.v.04'),
#   Synset('walk.v.05'),
#   Synset('walk.v.06'),
#   Synset('walk.v.07'),
#   Synset('walk.v.08'),
#   Synset('walk.v.09'),
#   Synset('walk.v.10'),
#   Synset('walk-to.s.01')],
#  'pocket': [Synset('pocket.n.01'),
#   Synset('pouch.n.02'),
#   Synset('pocket.n.03'),
#   Synset('pocket.n.04'),
#   Synset('scoop.n.02'),
#   Synset('air_pocket.n.01'),
#   Synset('pocket.n.07'),
#   Synset('pouch.n.03'),
#   Synset('pocket.n.09'),
#   Synset('pocket.v.01'),
#   Synset('pocket.v.02')],
#  'dumping': [Synset('dumping.n.01'),
#   Synset('dump.v.01'),
#   Synset('dump.v.02'),
#   Synset('dump.v.03'),
#   Synset('dump.v.04'),
#   Synset('plunge.v.06'),
#   Synset('deck.v.03')],
#  'hide': [Synset('hide.n.01'),
#   Synset('hide.n.02'),
#   Synset('hide.v.01'),
#   Synset('hide.v.02'),
#   Synset('shroud.v.01'),
#   Synset('obscure.v.05')],
#  'or': [Synset('oregon.n.01'), Synset('operating_room.n.01')],
#  'breathed': [Synset('breathe.v.01'),
#   Synset('breathe.v.02'),
#   Synset('breathe.v.03'),
#   Synset('breathe.v.04'),
#   Synset('breathe.v.05'),
#   Synset('breathe.v.06'),
#   Synset('rest.v.02'),
#   Synset('breathe.v.08'),
#   Synset('emit.v.01'),
#   Synset('breathed.s.01')],
#  'happy': [Synset('happy.a.01'),
#   Synset('felicitous.s.02'),
#   Synset('glad.s.02'),
#   Synset('happy.s.04')],
#  'Who': [Synset('world_health_organization.n.01')],
#  'pillow': [Synset('pillow.n.01'), Synset('pillow.v.01')],
#  'busy': [Synset('busy.v.01'),
#   Synset('busy.a.01'),
#   Synset('busy.s.02'),
#   Synset('interfering.s.01'),
#   Synset('busy.s.04'),
#   Synset('busy.s.05')],
#  'wobble': [Synset('wobble.n.01'),
#   Synset('wobble.v.01'),
#   Synset('careen.v.02'),
#   Synset('shimmy.v.01')],
#  'territory': [Synset('district.n.01'),
#   Synset('territory.n.02'),
#   Synset('territory.n.03')],
#  'Long': [Synset('hanker.v.01'),
#   Synset('long.a.01'),
#   Synset('long.a.02'),
#   Synset('long.s.03'),
#   Synset('retentive.a.01'),
#   Synset('long.a.05'),
#   Synset('long.a.06'),
#   Synset('long.s.07'),
#   Synset('farseeing.s.02'),
#   Synset('long.s.09'),
#   Synset('long.r.01'),
#   Synset('long.r.02')],
#  'lift': [Synset('lift.n.01'),
#   Synset('aerodynamic_lift.n.01'),
#   Synset('elevation.n.01'),
#   Synset('lift.n.04'),
#   Synset('ski_tow.n.01'),
#   Synset('lift.n.06'),
#   Synset('lift.n.07'),
#   Synset('elevator.n.01'),
#   Synset('face_lift.n.01'),
#   Synset('airlift.n.01'),
#   Synset('lift.n.11'),
#   Synset('lift.n.12'),
#   Synset('raise.v.02'),
#   Synset('lift.v.02'),
#   Synset('lift.v.03'),
#   Synset('rise.v.01'),
#   Synset('lift.v.05'),
#   Synset('revoke.v.02'),
#   Synset('pilfer.v.01'),
#   Synset('hoist.v.01'),
#   Synset('raise.v.25'),
#   Synset('lift.v.10'),
#   Synset('lift.v.11'),
#   Synset('rise.v.04'),
#   Synset('lift.v.13'),
#   Synset('plagiarize.v.01'),
#   Synset('rustle.v.02'),
#   Synset('airlift.v.01'),
#   Synset('lift.v.17'),
#   Synset('lift.v.18'),
#   Synset('lift.v.19'),
#   Synset('lift.v.20'),
#   Synset('lift.v.21'),
#   Synset('lift.v.22'),
#   Synset('lift.v.23'),
#   Synset('face-lift.v.01')],
#  'ripe': [Synset('ripe.a.01'),
#   Synset('ripe.s.02'),
#   Synset('good.s.12'),
#   Synset('ripe.s.04'),
#   Synset('advanced.s.06')],
#  'dispersed': [Synset('scatter.v.03'),
#   Synset('disperse.v.02'),
#   Synset('break_up.v.17'),
#   Synset('disperse.v.04'),
#   Synset('disperse.v.05'),
#   Synset('circulate.v.02'),
#   Synset('dispersed.s.01')],
#  'smell': [Synset('smell.n.01'),
#   Synset('olfactory_property.n.01'),
#   Synset('spirit.n.02'),
#   Synset('smell.n.04'),
#   Synset('smell.n.05'),
#   Synset('smell.v.01'),
#   Synset('smell.v.02'),
#   Synset('smell.v.03'),
#   Synset('smack.v.02'),
#   Synset('smell.v.05')],
#  'guided': [Synset('steer.v.01'),
#   Synset('lead.v.01'),
#   Synset('guide.v.03'),
#   Synset('guide.v.04'),
#   Synset('guide.v.05'),
#   Synset('guided.a.01')],
#  'reminder': [Synset('reminder.n.01'),
#   Synset('reminder.n.02'),
#   Synset('admonisher.n.01')],
#  'now': [Synset('now.n.01'),
#   Synset('now.r.01'),
#   Synset('nowadays.r.01'),
#   Synset('now.r.03'),
#   Synset('now.r.04'),
#   Synset('immediately.r.01'),
#   Synset('now.r.06'),
#   Synset('now.r.07')],
#  'must': [Synset('must.n.01'),
#   Synset('must.n.02'),
#   Synset('mustiness.n.01'),
#   Synset('must.s.01')],
#  'normal': [Synset('convention.n.02'),
#   Synset('normal.a.01'),
#   Synset('normal.a.02'),
#   Synset('normal.a.03'),
#   Synset('normal.s.04')],
#  'chapter': [Synset('chapter.n.01'),
#   Synset('chapter.n.02'),
#   Synset('chapter.n.03'),
#   Synset('chapter.n.04'),
#   Synset('chapter.n.05')],
#  'still': [Synset('still.n.01'),
#   Synset('hush.n.01'),
#   Synset('still.n.03'),
#   Synset('distillery.n.01'),
#   Synset('calm.v.01'),
#   Synset('hush.v.02'),
#   Synset('still.v.03'),
#   Synset('still.v.04'),
#   Synset('inactive.s.10'),
#   Synset('silent.s.01'),
#   Synset('placid.s.01'),
#   Synset('still.a.04'),
#   Synset('still.a.05'),
#   Synset('still.s.06'),
#   Synset('still.r.01'),
#   Synset('however.r.01'),
#   Synset('even.r.03'),
#   Synset('still.r.04')],
#  'noticed': [Synset('detect.v.01'),
#   Synset('notice.v.02'),
#   Synset('comment.v.01'),
#   Synset('notice.v.04'),
#   Synset('noticed.a.01')],
#  'thin': [Synset('thin.v.01'),
#   Synset('thin.v.02'),
#   Synset('dilute.v.01'),
#   Synset('reduce.v.20'),
#   Synset('thin.a.01'),
#   Synset('thin.a.02'),
#   Synset('slender.s.02'),
#   Synset('sparse.s.01'),
#   Synset('thin.a.05'),
#   Synset('thin.a.06'),
#   Synset('thin.s.07'),
#   Synset('flimsy.s.03'),
#   Synset('thinly.r.02')],
#  'mentioned': [Synset('mention.v.01'),
#   Synset('note.v.01'),
#   Synset('mention.v.03')],
#  'toast': [Synset('toast.n.01'),
#   Synset('toast.n.02'),
#   Synset('goner.n.01'),
#   Synset('pledge.n.03'),
#   Synset('crispen.v.01'),
#   Synset('toast.v.02')],
#  'mentioning': [Synset('mention.v.01'),
#   Synset('note.v.01'),
#   Synset('mention.v.03')],
#  'thank': [Synset('thank.v.01')],
#  'rethought': [Synset('rethink.v.01')],
#  'ears': [Synset('ear.n.01'),
#   Synset('ear.n.02'),
#   Synset('auricle.n.02'),
#   Synset('ear.n.04'),
#   Synset('ear.n.05')],
#  'wrinkly': [Synset('wrinkled.a.01')],
#  'drop': [Synset('drop.n.01'),
#   Synset('drop.n.02'),
#   Synset('drop.n.03'),
#   Synset('cliff.n.01'),
#   Synset('drop.n.05'),
#   Synset('drop.n.06'),
#   Synset('drop_curtain.n.01'),
#   Synset('drop.n.08'),
#   Synset('drop.n.09'),
#   Synset('drop.v.01'),
#   Synset('drop.v.02'),
#   Synset('drop.v.03'),
#   Synset('sink.v.01'),
#   Synset('drop.v.05'),
#   Synset('drop.v.06'),
#   Synset('drop.v.07'),
#   Synset('drop.v.08'),
#   Synset('fell.v.01'),
#   Synset('drop.v.10'),
#   Synset('spend.v.02'),
#   Synset('flatten.v.03'),
#   Synset('dangle.v.01'),
#   Synset('dismiss.v.03'),
#   Synset('dribble.v.02'),
#   Synset('shed.v.01'),
#   Synset('drop.v.17'),
#   Synset('drop.v.18'),
#   Synset('neglect.v.01'),
#   Synset('drop.v.20'),
#   Synset('drop.v.21'),
#   Synset('devolve.v.03'),
#   Synset('drop.v.23')],
#  'buy': [Synset('bargain.n.02'),
#   Synset('buy.v.01'),
#   Synset('bribe.v.01'),
#   Synset('buy.v.03'),
#   Synset('buy.v.04'),
#   Synset('buy.v.05')],
#  'thanked': [Synset('thank.v.01')],
#  'expectant': [Synset('anticipant.s.01'), Synset('big.s.13')],
#  'sashayed': [Synset('sidle.v.02'),
#   Synset('tittup.v.01'),
#   Synset('chasse.v.01')],
#  'blood': [Synset('blood.n.01'),
#   Synset('blood.n.02'),
#   Synset('rake.n.01'),
#   Synset('lineage.n.01'),
#   Synset('blood.n.05'),
#   Synset('blood.v.01')],
#  'gate': [Synset('gate.n.01'),
#   Synset('gate.n.02'),
#   Synset('gate.n.03'),
#   Synset('gate.n.04'),
#   Synset('gate.v.01'),
#   Synset('gate.v.02'),
#   Synset('gate.v.03')],
#  '20': [Synset('twenty.n.01'), Synset('twenty.s.01')],
#  'conceive': [Synset('gestate.v.01'),
#   Synset('think.v.01'),
#   Synset('conceive.v.03')],
#  'around': [Synset('about.r.03'),
#   Synset('around.r.02'),
#   Synset('about.r.04'),
#   Synset('around.r.04'),
#   Synset('approximately.r.01'),
#   Synset('about.r.05'),
#   Synset('around.r.07'),
#   Synset('about.r.02'),
#   Synset('around.r.09'),
#   Synset('round.r.01')],
#  'towel': [Synset('towel.n.01'), Synset('towel.v.01')],
#  'MINE': [Synset('mine.n.01'),
#   Synset('mine.n.02'),
#   Synset('mine.v.01'),
#   Synset('mine.v.02')],
#  'examination': [Synset('examination.n.01'),
#   Synset('examination.n.02'),
#   Synset('interrogation.n.03'),
#   Synset('examen.n.01'),
#   Synset('examination.n.05')],
#  'married': [Synset('married.n.01'),
#   Synset('marry.v.01'),
#   Synset('marry.v.02'),
#   Synset('married.a.01'),
#   Synset('marital.a.01')],
#  'widening': [Synset('widening.n.01'),
#   Synset('turnout.n.02'),
#   Synset('widening.n.03'),
#   Synset('widen.v.01'),
#   Synset('let_out.v.04'),
#   Synset('widen.v.03'),
#   Synset('widen.v.04')],
#  'rose': [Synset('rose.n.01'),
#   Synset('blush_wine.n.01'),
#   Synset('rose.n.03'),
#   Synset('rise.v.01'),
#   Synset('rise.v.02'),
#   Synset('arise.v.03'),
#   Synset('rise.v.04'),
#   Synset('surface.v.01'),
#   Synset('originate.v.01'),
#   Synset('ascend.v.08'),
#   Synset('wax.v.02'),
#   Synset('heighten.v.01'),
#   Synset('get_up.v.02'),
#   Synset('rise.v.11'),
#   Synset('rise.v.12'),
#   Synset('rise.v.13'),
#   Synset('rebel.v.01'),
#   Synset('rise.v.15'),
#   Synset('rise.v.16'),
#   Synset('resurrect.v.03'),
#   Synset('rose.s.01')],
#  'snatched': [Synset('snatch.v.01'),
#   Synset('snatch.v.02'),
#   Synset('kidnap.v.01')],
#  'question': [Synset('question.n.01'),
#   Synset('question.n.02'),
#   Synset('question.n.03'),
#   Synset('doubt.n.02'),
#   Synset('motion.n.05'),
#   Synset('question.n.06'),
#   Synset('question.v.01'),
#   Synset('interrogate.v.02'),
#   Synset('question.v.03'),
#   Synset('interview.v.01'),
#   Synset('wonder.v.02')],
#  'mumbles': [Synset('mumble.n.01'),
#   Synset('mumble.v.01'),
#   Synset('mumble.v.02')],
#  'Sunday': [Synset('sunday.n.01'), Synset('sunday.n.02')],
#  'halfway': [Synset('center.s.01'),
#   Synset('halfway.s.02'),
#   Synset('halfway.s.03'),
#   Synset('halfway.r.01')],
#  'upside': [Synset('top.n.02')],
#  'hot': [Synset('hot.a.01'),
#   Synset('hot.s.02'),
#   Synset('hot.a.03'),
#   Synset('hot.s.04'),
#   Synset('hot.s.05'),
#   Synset('hot.s.06'),
#   Synset('blistering.s.03'),
#   Synset('hot.s.08'),
#   Synset('hot.s.09'),
#   Synset('hot.s.10'),
#   Synset('hot.s.11'),
#   Synset('hot.s.12'),
#   Synset('hot.s.13'),
#   Synset('hot.s.14'),
#   Synset('hot.s.15'),
#   Synset('hot.s.16'),
#   Synset('hot.s.17'),
#   Synset('hot.s.18'),
#   Synset('hot.s.19'),
#   Synset('hot.s.20'),
#   Synset('hot.s.21')],
#  'watching': [Synset('observation.n.02'),
#   Synset('watch.v.01'),
#   Synset('watch.v.02'),
#   Synset('watch.v.03'),
#   Synset('watch.v.04'),
#   Synset('watch.v.05'),
#   Synset('watch.v.06'),
#   Synset('determine.v.08')],
#  'cheek': [Synset('cheek.n.01'),
#   Synset('impudence.n.01'),
#   Synset('buttock.n.01'),
#   Synset('boldness.n.02'),
#   Synset('cheek.v.01')],
#  'dark': [Synset('dark.n.01'),
#   Synset('iniquity.n.01'),
#   Synset('darkness.n.02'),
#   Synset('night.n.01'),
#   Synset('dark.n.05'),
#   Synset('dark.a.01'),
#   Synset('dark.a.02'),
#   Synset('dark.s.03'),
#   Synset('black.s.05'),
#   Synset('dark.s.05'),
#   Synset('dark.s.06'),
#   Synset('benighted.s.02'),
#   Synset('dark.s.08'),
#   Synset('blue.s.08'),
#   Synset('colored.s.02'),
#   Synset('dark.s.11')],
#  'tone': [Synset('tone.n.01'),
#   Synset('tone.n.02'),
#   Synset('timbre.n.01'),
#   Synset('spirit.n.02'),
#   Synset('shade.n.02'),
#   Synset('note.n.03'),
#   Synset('tone.n.07'),
#   Synset('tonicity.n.01'),
#   Synset('tone.n.09'),
#   Synset('tone.n.10'),
#   Synset('tone.v.01'),
#   Synset('tone.v.02'),
#   Synset('tone.v.03'),
#   Synset('tone.v.04'),
#   Synset('tone.v.05')],
#  'basic': [Synset('basic.n.01'),
#   Synset('basic.n.02'),
#   Synset('basic.a.01'),
#   Synset('basic.s.02'),
#   Synset('basic.s.03'),
#   Synset('basic.s.04')],
#  'freaked': [Synset('freak_out.v.01')],
#  'notary': [Synset('notary.n.01')],
#  'engine': [Synset('engine.n.01'),
#   Synset('engine.n.02'),
#   Synset('locomotive.n.01'),
#   Synset('engine.n.04')],
#  'awful': [Synset('atrocious.s.02'),
#   Synset('awful.s.02'),
#   Synset('nasty.a.01'),
#   Synset('awed.s.01'),
#   Synset('frightful.s.02'),
#   Synset('amazing.s.02'),
#   Synset('terribly.r.01')],
#  'simple': [Synset('simple.n.01'),
#   Synset('simpleton.n.01'),
#   Synset('simple.a.01'),
#   Synset('elementary.s.01'),
#   Synset('bare.s.06'),
#   Synset('childlike.s.02'),
#   Synset('dim-witted.s.01'),
#   Synset('simple.a.06'),
#   Synset('simple.s.07')],
#  'imagining': [Synset('imagine.v.01'), Synset('think.v.02')],
#  'collect': [Synset('collect.n.01'),
#   Synset('roll_up.v.02'),
#   Synset('collect.v.02'),
#   Synset('gather.v.01'),
#   Synset('collect.v.04'),
#   Synset('collect.v.05'),
#   Synset('collect.s.01'),
#   Synset('collect.r.01')],
#  'forgetting': [Synset('forget.v.01'),
#   Synset('forget.v.02'),
#   Synset('forget.v.03'),
#   Synset('forget.v.04')],
#  'tear': [Synset('tear.n.01'),
#   Synset('rip.n.02'),
#   Synset('bust.n.04'),
#   Synset('tear.n.04'),
#   Synset('tear.v.01'),
#   Synset('tear.v.02'),
#   Synset('tear.v.03'),
#   Synset('pluck.v.05'),
#   Synset('tear.v.05')],
#  'settled': [Synset('settle.v.01'),
#   Synset('decide.v.02'),
#   Synset('settle.v.03'),
#   Synset('settle.v.04'),
#   Synset('reconcile.v.03'),
#   Synset('sink.v.04'),
#   Synset('settle.v.07'),
#   Synset('settle.v.08'),
#   Synset('settle.v.09'),
#   Synset('settle.v.10'),
#   Synset('settle.v.11'),
#   Synset('settle.v.12'),
#   Synset('settle.v.13'),
#   Synset('settle.v.14'),
#   Synset('settle.v.15'),
#   Synset('settle.v.16'),
#   Synset('subside.v.03'),
#   Synset('ensconce.v.01'),
#   Synset('settle.v.19'),
#   Synset('finalize.v.01'),
#   Synset('settle.v.21'),
#   Synset('fall.v.32'),
#   Synset('settled.a.01'),
#   Synset('settled.a.02'),
#   Synset('colonized.s.01'),
#   Synset('settled.s.04')],
#  'Anyway': [Synset('anyhow.r.01'), Synset('anyhow.r.02')],
#  'partner': [Synset('spouse.n.01'),
#   Synset('collaborator.n.03'),
#   Synset('partner.n.03'),
#   Synset('partner.v.01'),
#   Synset('partner.v.02')],
#  'outside': [Synset('outside.n.01'),
#   Synset('outside.n.02'),
#   Synset('outside.a.01'),
#   Synset('external.s.02'),
#   Synset('outside.s.03'),
#   Synset('outdoor.a.01'),
#   Synset('outside.s.05'),
#   Synset('outside.s.06'),
#   Synset('external.s.03'),
#   Synset('outside.s.08'),
#   Synset('outside.s.09'),
#   Synset('away.s.03'),
#   Synset('outside.r.01'),
#   Synset('outside.r.02')],
#  'both': [Synset('both.s.01')],
#  'fill': [Synset('fill.n.01'),
#   Synset('filling.n.01'),
#   Synset('fill.v.01'),
#   Synset('fill.v.02'),
#   Synset('occupy.v.03'),
#   Synset('fill.v.04'),
#   Synset('meet.v.04'),
#   Synset('fill.v.06'),
#   Synset('fill_up.v.04'),
#   Synset('satiate.v.01'),
#   Synset('fill.v.09')],
#  'releasing': [Synset('let_go_of.v.01'),
#   Synset('free.v.01'),
#   Synset('turn.v.08'),
#   Synset('publish.v.02'),
#   Synset('exhaust.v.05'),
#   Synset('secrete.v.01'),
#   Synset('free.v.05'),
#   Synset('release.v.08'),
#   Synset('release.v.09'),
#   Synset('unblock.v.03'),
#   Synset('cathartic.s.02')],
#  'finish': [Synset('coating.n.02'),
#   Synset('stopping_point.n.01'),
#   Synset('polish.n.02'),
#   Synset('finish.n.04'),
#   Synset('finish.n.05'),
#   Synset('finish.n.06'),
#   Synset('ending.n.04'),
#   Synset('finish.n.08'),
#   Synset('finish.n.09'),
#   Synset('complete.v.01'),
#   Synset('finish_up.v.02'),
#   Synset('end.v.01'),
#   Synset('finish.v.04'),
#   Synset('eat_up.v.01'),
#   Synset('finish.v.06')],
#  'explanation': [Synset('explanation.n.01'),
#   Synset('explanation.n.02'),
#   Synset('explanation.n.03')],
#  'lovingly': [Synset('fondly.r.01')],
#  'friends': [Synset('friend.n.01'),
#   Synset('ally.n.02'),
#   Synset('acquaintance.n.03'),
#   Synset('supporter.n.01'),
#   Synset('friend.n.05')],
#  'seven': [Synset('seven.n.01'),
#   Synset('seven-spot.n.01'),
#   Synset('seven.s.01')],
#  'heaven': [Synset('eden.n.01'), Synset('heaven.n.02')],
#  'well': [Synset('well.n.01'),
#   Synset('well.n.02'),
#   Synset('well.n.03'),
#   Synset('well.n.04'),
#   Synset('well.n.05'),
#   Synset('well.v.01'),
#   Synset('well.a.01'),
#   Synset('good.s.13'),
#   Synset('well.s.03'),
#   Synset('well.r.01'),
#   Synset('well.r.02'),
#   Synset('well.r.03'),
#   Synset('well.r.04'),
#   Synset('well.r.05'),
#   Synset('well.r.06'),
#   Synset('well.r.07'),
#   Synset('well.r.08'),
#   Synset('well.r.09'),
#   Synset('well.r.10'),
#   Synset('well.r.11'),
#   Synset('well.r.12'),
#   Synset('well.r.13')],
#  'Cool': [Synset('cool.n.01'),
#   Synset('aplomb.n.01'),
#   Synset('cool.v.01'),
#   Synset('cool.v.02'),
#   Synset('cool.v.03'),
#   Synset('cool.a.01'),
#   Synset('cool.s.02'),
#   Synset('cool.a.03'),
#   Synset('cool.a.04'),
#   Synset('cool.s.05'),
#   Synset('cool.s.06')],
#  'easier': [Synset('easy.a.01'),
#   Synset('easy.s.02'),
#   Synset('easy.a.03'),
#   Synset('easy.s.04'),
#   Synset('easy.s.05'),
#   Synset('easy.s.06'),
#   Synset('comfortable.s.05'),
#   Synset('easy.s.08'),
#   Synset('easy.s.09'),
#   Synset('easy.s.10'),
#   Synset('easy.s.11'),
#   Synset('easy.s.12')],
#  'silently': [Synset('mutely.r.01')],
#  'Someone': [Synset('person.n.01')],
#  'weirdly': [Synset('weirdly.r.01')],
#  'reaching': [Synset('reach.n.03'),
#   Synset('arrival.n.01'),
#   Synset('reach.v.01'),
#   Synset('reach.v.02'),
#   Synset('reach.v.03'),
#   Synset('reach.v.04'),
#   Synset('achieve.v.01'),
#   Synset('reach.v.06'),
#   Synset('reach.v.07'),
#   Synset('pass.v.05'),
#   Synset('strive.v.02')],
#  'asleep': [Synset('asleep.a.01'),
#   Synset('asleep.s.02'),
#   Synset('asleep.s.03'),
#   Synset('asleep.r.01'),
#   Synset('asleep.r.02')],
#  'pin': [Synset('pin.n.01'),
#   Synset('fall.n.10'),
#   Synset('peg.n.02'),
#   Synset('personal_identification_number.n.01'),
#   Synset('pin.n.05'),
#   Synset('pivot.n.02'),
#   Synset('pin.n.07'),
#   Synset('pin.n.08'),
#   Synset('pin.n.09'),
#   Synset('peg.n.06'),
#   Synset('bowling_pin.n.01'),
#   Synset('trap.v.04'),
#   Synset('pin.v.02'),
#   Synset('pin.v.03'),
#   Synset('pin.v.04')],
#  'STRESS': [Synset('stress.n.01'),
#   Synset('tension.n.01'),
#   Synset('stress.n.03'),
#   Synset('stress.n.04'),
#   Synset('stress.n.05'),
#   Synset('stress.v.01'),
#   Synset('stress.v.02'),
#   Synset('try.v.07')],
#  'punched': [Synset('punch.v.01'), Synset('punch.v.02'), Synset('punch.v.03')],
#  'contagious': [Synset('contagious.s.01'), Synset('catching.s.01')],
#  '8': [Synset('eight.n.01'), Synset('eight.s.01')],
#  'material': [Synset('material.n.01'),
#   Synset('material.n.02'),
#   Synset('fabric.n.01'),
#   Synset('material.n.04'),
#   Synset('material.n.05'),
#   Synset('material.s.01'),
#   Synset('material.a.02'),
#   Synset('material.a.03'),
#   Synset('material.s.04'),
#   Synset('corporeal.a.01'),
#   Synset('substantial.a.03')],
#  'p.m.': [Synset('post_meridiem.s.01'), Synset('post_meridiem.r.01')],
#  'angel': [Synset('angel.n.01'),
#   Synset('saint.n.02'),
#   Synset('angel.n.03'),
#   Synset('angel.n.04')],
#  'eggs': [Synset('egg.n.02'),
#   Synset('egg.n.01'),
#   Synset('egg.n.02'),
#   Synset('testis.n.01'),
#   Synset('egg.v.01'),
#   Synset('egg.v.02')],
#  'eyebrows': [Synset('eyebrow.n.01')],
#  'blackmail': [Synset('blackmail.n.01'),
#   Synset('blackmail.v.01'),
#   Synset('blackmail.v.02')],
#  'curled': [Synset('curl.v.01'),
#   Synset('curl_up.v.01'),
#   Synset('coil.v.03'),
#   Synset('curl.v.04'),
#   Synset('curl.v.05'),
#   Synset('curled.s.01')],
#  'motherly': [Synset('motherly.s.01'), Synset('maternally.r.01')],
#  'cousins': [Synset('cousin.n.01')],
#  'flight': [Synset('flight.n.01'),
#   Synset('flight.n.02'),
#   Synset('flight.n.03'),
#   Synset('escape.n.01'),
#   Synset('flight.n.05'),
#   Synset('flight.n.06'),
#   Synset('trajectory.n.01'),
#   Synset('flight.n.08'),
#   Synset('flight.n.09'),
#   Synset('flight.v.01'),
#   Synset('flight.v.02'),
#   Synset('fledge.v.02')],
#  'camera': [Synset('camera.n.01'), Synset('television_camera.n.01')],
#  'refrigerator': [Synset('refrigerator.n.01')],
#  'glowed': [Synset('glow.v.01'),
#   Synset('glow.v.02'),
#   Synset('burn.v.02'),
#   Synset('glow.v.04'),
#   Synset('glow.v.05')],
#  'before': [Synset('earlier.r.01'), Synset('ahead.r.01')],
#  'amendments': [Synset('amendment.n.01'), Synset('amendment.n.02')],
#  'actually': [Synset('actually.r.01'),
#   Synset('actually.r.02'),
#   Synset('actually.r.03'),
#   Synset('actually.r.04')],
#  'three': [Synset('three.n.01'), Synset('trey.n.02'), Synset('three.s.01')],
#  'enjoy': [Synset('enjoy.v.01'),
#   Synset('enjoy.v.02'),
#   Synset('love.v.02'),
#   Synset('enjoy.v.04'),
#   Synset('delight.v.02')],
#  'voice': [Synset('voice.n.01'),
#   Synset('voice.n.02'),
#   Synset('voice.n.03'),
#   Synset('articulation.n.03'),
#   Synset('voice.n.05'),
#   Synset('voice.n.06'),
#   Synset('voice.n.07'),
#   Synset('spokesperson.n.01'),
#   Synset('voice.n.09'),
#   Synset('voice.n.10'),
#   Synset('part.n.11'),
#   Synset('voice.v.01'),
#   Synset('voice.v.02')],
#  'wonderfully': [Synset('wonderfully.r.01')],
#  'kitchen': [Synset('kitchen.n.01')],
#  'heads': [Synset('head.n.01'),
#   Synset('head.n.02'),
#   Synset('mind.n.01'),
#   Synset('head.n.04'),
#   Synset('head.n.05'),
#   Synset('head.n.06'),
#   Synset('head.n.07'),
#   Synset('fountainhead.n.02'),
#   Synset('head.n.09'),
#   Synset('head.n.10'),
#   Synset('head.n.11'),
#   Synset('capitulum.n.01'),
#   Synset('principal.n.02'),
#   Synset('head.n.14'),
#   Synset('head.n.15'),
#   Synset('promontory.n.01'),
#   Synset('head.n.17'),
#   Synset('head.n.18'),
#   Synset('forefront.n.01'),
# ...
#  'squeeze': [Synset('squeeze.n.01'),
#   Synset('credit_crunch.n.01'),
#   Synset('squeeze.n.03'),
#   Synset('squeeze.n.04'),
#   Synset('squeeze.n.05'),
#   Synset('power_play.n.01'),
#   Synset('hug.n.01'),
#   Synset('squeeze.n.08'),
#   Synset('squash.v.01'),
#   Synset('squeeze.v.02'),
#   Synset('wedge.v.02'),
#   Synset('coerce.v.01'),
#   Synset('extort.v.02'),
#   Synset('thrust.v.02'),
#   Synset('pinch.v.01'),
#   Synset('embrace.v.02'),
#   Synset('compress.v.02')],
#  'nobody': [Synset('cipher.n.04')],
#  'almost': [Synset('about.r.07')],
#  'convince': [Synset('convert.v.09')],
#  'dealing': [Synset('dealing.n.01'),
#   Synset('transaction.n.01'),
#   Synset('cover.v.05'),
#   Synset('consider.v.03'),
#   Synset('deal.v.03'),
#   Synset('cope.v.01'),
#   Synset('distribute.v.01'),
#   Synset('deal.v.06'),
#   Synset('manage.v.02'),
#   Synset('deal.v.08'),
#   Synset('deal.v.09'),
#   Synset('conduct.v.01'),
#   Synset('share.v.04'),
#   Synset('deal.v.12'),
#   Synset('deal.v.13')],
#  'note': [Synset('note.n.01'),
#   Synset('note.n.02'),
#   Synset('note.n.03'),
#   Synset('note.n.04'),
#   Synset('note.n.05'),
#   Synset('bill.n.03'),
#   Synset('note.n.07'),
#   Synset('eminence.n.01'),
#   Synset('note.n.09'),
#   Synset('note.v.01'),
#   Synset('notice.v.02'),
#   Synset('note.v.03'),
#   Synset('note.v.04')],
#  'true': [Synset('true.n.01'),
#   Synset('true.v.01'),
#   Synset('true.a.01'),
#   Synset('true.s.02'),
#   Synset('true.s.03'),
#   Synset('truthful.a.01'),
#   Synset('true.s.05'),
#   Synset('dependable.s.02'),
#   Synset('genuine.s.02'),
#   Synset('true.s.08'),
#   Synset('true.s.09'),
#   Synset('true.s.10'),
#   Synset('on-key.s.01'),
#   Synset('true.s.12'),
#   Synset('true.r.01')],
#  'escaped': [Synset('escape.v.01'),
#   Synset('miss.v.09'),
#   Synset('get_off.v.05'),
#   Synset('elude.v.02'),
#   Synset('escape.v.05'),
#   Synset('scat.v.01'),
#   Synset('escape.v.07'),
#   Synset('at_large.s.01')],
#  'However': [Synset('however.r.01'),
#   Synset('however.r.02'),
#   Synset('however.r.03'),
#   Synset('however.r.04')],
#  'purse': [Synset('bag.n.04'),
#   Synset('purse.n.02'),
#   Synset('purse.n.03'),
#   Synset('purse.n.04'),
#   Synset('purse.v.01'),
#   Synset('purse.v.02')],
#  'consumed': [Synset('devour.v.03'),
#   Synset('consume.v.02'),
#   Synset('consume.v.03'),
#   Synset('consume.v.04'),
#   Synset('consume.v.05'),
#   Synset('consume.v.06')],
#  'Enough': [Synset('enough.n.01'),
#   Synset('adequate.s.02'),
#   Synset('enough.r.01')],
#  'dropping': [Synset('drop.v.01'),
#   Synset('drop.v.02'),
#   Synset('drop.v.03'),
#   Synset('sink.v.01'),
#   Synset('drop.v.05'),
#   Synset('drop.v.06'),
#   Synset('drop.v.07'),
#   Synset('drop.v.08'),
#   Synset('fell.v.01'),
#   Synset('drop.v.10'),
#   Synset('spend.v.02'),
#   Synset('flatten.v.03'),
#   Synset('dangle.v.01'),
#   Synset('dismiss.v.03'),
#   Synset('dribble.v.02'),
#   Synset('shed.v.01'),
#   Synset('drop.v.17'),
#   Synset('drop.v.18'),
#   Synset('neglect.v.01'),
#   Synset('drop.v.20'),
#   Synset('drop.v.21'),
#   Synset('devolve.v.03'),
#   Synset('drop.v.23'),
#   Synset('dropping.s.01')],
#  'day': [Synset('day.n.01'),
#   Synset('day.n.02'),
#   Synset('day.n.03'),
#   Synset('day.n.04'),
#   Synset('day.n.05'),
#   Synset('day.n.06'),
#   Synset('day.n.07'),
#   Synset('sidereal_day.n.01'),
#   Synset('day.n.09'),
#   Synset('day.n.10')],
#  'back': [Synset('back.n.01'),
#   Synset('rear.n.05'),
#   Synset('back.n.03'),
#   Synset('back.n.04'),
#   Synset('spinal_column.n.01'),
#   Synset('binding.n.05'),
#   Synset('back.n.07'),
#   Synset('back.n.08'),
#   Synset('back.n.09'),
#   Synset('back.v.01'),
#   Synset('back.v.02'),
#   Synset('second.v.01'),
#   Synset('back.v.04'),
#   Synset('back.v.05'),
#   Synset('back.v.06'),
#   Synset('bet_on.v.01'),
#   Synset('back.v.08'),
#   Synset('back.v.09'),
#   Synset('back.v.10'),
#   Synset('back.a.01'),
#   Synset('back.s.02'),
#   Synset('back.s.03'),
#   Synset('back.r.01'),
#   Synset('back.r.02'),
#   Synset('back.r.03'),
#   Synset('back.r.04'),
#   Synset('back.r.05'),
#   Synset('back.r.06')],
#  'life': [Synset('life.n.01'),
#   Synset('life.n.02'),
#   Synset('life.n.03'),
#   Synset('animation.n.01'),
#   Synset('life.n.05'),
#   Synset('life.n.06'),
#   Synset('life.n.07'),
#   Synset('life.n.08'),
#   Synset('liveliness.n.02'),
#   Synset('life.n.10'),
#   Synset('life.n.11'),
#   Synset('biography.n.01'),
#   Synset('life.n.13'),
#   Synset('life_sentence.n.01')],
#  'kids': [Synset('child.n.01'),
#   Synset('kid.n.02'),
#   Synset('kyd.n.01'),
#   Synset('child.n.02'),
#   Synset('kid.n.05'),
#   Synset('pull_the_leg_of.v.01'),
#   Synset('kid.v.02')],
#  'blur': [Synset('blur.n.01'),
#   Synset('film_over.v.01'),
#   Synset('blur.v.02'),
#   Synset('confuse.v.05'),
#   Synset('smear.v.02'),
#   Synset('blur.v.05'),
#   Synset('blur.v.06')],
#  'enters': [Synset('enter.v.01'),
#   Synset('enter.v.02'),
#   Synset('enroll.v.01'),
#   Synset('figure.v.02'),
#   Synset('record.v.01'),
#   Synset('enter.v.06'),
#   Synset('accede.v.02'),
#   Synset('insert.v.01'),
#   Synset('embark.v.02')],
#  'grimaced': [Synset('grimace.v.01')],
#  'Friday': [Synset('friday.n.01')],
#  'Bloody': [Synset('bloody.v.01'),
#   Synset('bloody.a.01'),
#   Synset('bally.s.01'),
#   Synset('bloody.r.01')],
#  'smorgasbord': [Synset('assortment.n.01'), Synset('smorgasbord.n.02')],
#  'putting': [Synset('putt.n.01'),
#   Synset('put.v.01'),
#   Synset('put.v.02'),
#   Synset('frame.v.04'),
#   Synset('put.v.04'),
#   Synset('invest.v.01'),
#   Synset('place.v.11'),
#   Synset('put.v.07'),
#   Synset('put.v.08'),
#   Synset('arrange.v.07')],
#  'Do': [Synset('bash.n.02'),
#   Synset('do.n.02'),
#   Synset('doctor_of_osteopathy.n.01'),
#   Synset('make.v.01'),
#   Synset('perform.v.01'),
#   Synset('do.v.03'),
#   Synset('do.v.04'),
#   Synset('cause.v.01'),
#   Synset('practice.v.01'),
#   Synset('suffice.v.01'),
#   Synset('do.v.08'),
#   Synset('act.v.02'),
#   Synset('serve.v.09'),
#   Synset('do.v.11'),
#   Synset('dress.v.16'),
#   Synset('do.v.13')],
#  'Yeah': [Synset('yea.r.01')],
#  'tosses': [Synset('flip.n.04'),
#   Synset('pass.n.15'),
#   Synset('toss.n.03'),
#   Synset('flip.v.06'),
#   Synset('flip.v.01'),
#   Synset('chuck.v.01'),
#   Synset('convulse.v.03'),
#   Synset('discard.v.01'),
#   Synset('toss.v.06')],
#  'calm': [Synset('composure.n.01'),
#   Synset('calm_air.n.01'),
#   Synset('calm.v.01'),
#   Synset('steady.v.01'),
#   Synset('calm.v.03'),
#   Synset('sedate.v.01'),
#   Synset('calm.s.01'),
#   Synset('calm.a.02')],
#  'grinned': [Synset('grin.v.01')],
#  'car': [Synset('car.n.01'),
#   Synset('car.n.02'),
#   Synset('car.n.03'),
#   Synset('car.n.04'),
#   Synset('cable_car.n.01')],
#  'Let': [Synset('lashkar-e-taiba.n.01'),
#   Synset('let.n.02'),
#   Synset('let.v.01'),
#   Synset('let.v.02'),
#   Synset('permit.v.01'),
#   Synset('get.v.03'),
#   Synset('let.v.05'),
#   Synset('lease.v.03')],
#  'drawn': [Synset('pull.v.01'),
#   Synset('reap.v.02'),
#   Synset('trace.v.02'),
#   Synset('draw.v.04'),
#   Synset('draw.v.05'),
#   Synset('draw.v.06'),
#   Synset('draw.v.07'),
#   Synset('describe.v.01'),
#   Synset('draw.v.09'),
#   Synset('draw.v.10'),
#   Synset('puff.v.02'),
#   Synset('draw.v.12'),
#   Synset('withdraw.v.09'),
#   Synset('draw.v.14'),
#   Synset('draw.v.15'),
#   Synset('draw.v.16'),
#   Synset('draw.v.17'),
#   Synset('draw.v.18'),
#   Synset('draw.v.19'),
#   Synset('draw.v.20'),
#   Synset('draw.v.21'),
#   Synset('draw.v.22'),
#   Synset('draw.v.23'),
#   Synset('pull.v.09'),
#   Synset('absorb.v.04'),
#   Synset('attract.v.01'),
#   Synset('string.v.01'),
#   Synset('pull_back.v.04'),
#   Synset('guide.v.05'),
#   Synset('tie.v.02'),
#   Synset('draw.v.31'),
#   Synset('draw.v.32'),
#   Synset('draw.v.33'),
#   Synset('disembowel.v.01'),
#   Synset('draw.v.35'),
#   Synset('draw.v.36'),
#   Synset('careworn.s.01'),
#   Synset('drawn.s.02')],
#  'blonde': [Synset('blond.n.01'), Synset('blond.n.02'), Synset('blond.a.01')],
#  'ear': [Synset('ear.n.01'),
#   Synset('ear.n.02'),
#   Synset('auricle.n.02'),
#   Synset('ear.n.04'),
#   Synset('ear.n.05')],
#  'character': [Synset('fictional_character.n.01'),
#   Synset('quality.n.03'),
#   Synset('character.n.03'),
#   Synset('character.n.04'),
#   Synset('character.n.05'),
#   Synset('character.n.06'),
#   Synset('character.n.07'),
#   Synset('character.n.08'),
#   Synset('character.n.09'),
#   Synset('character.v.01')],
#  'sounded': [Synset('sound.v.01'),
#   Synset('sound.v.02'),
#   Synset('sound.v.03'),
#   Synset('sound.v.04'),
#   Synset('voice.v.02'),
#   Synset('sound.v.06'),
#   Synset('fathom.v.02')],
#  'crazy': [Synset('crazy.n.01'),
#   Synset('brainsick.s.01'),
#   Synset('crazy.s.02'),
#   Synset('crazy.s.03'),
#   Synset('crazy.s.04'),
#   Synset('crazy.s.05')],
#  'causing': [Synset('causing.n.01'),
#   Synset('cause.v.01'),
#   Synset('induce.v.02')],
#  'sometimes': [Synset('sometimes.r.01')],
#  'wall': [Synset('wall.n.01'),
#   Synset('wall.n.02'),
#   Synset('wall.n.03'),
#   Synset('wall.n.04'),
#   Synset('wall.n.05'),
#   Synset('wall.n.06'),
#   Synset('wall.n.07'),
#   Synset('rampart.n.01'),
#   Synset('wall.v.01')],
#  'lane': [Synset('lane.n.01'), Synset('lane.n.02')],
#  'sitting': [Synset('sitting.n.01'),
#   Synset('sitting.n.02'),
#   Synset('seance.n.01'),
#   Synset('sitting.n.04'),
#   Synset('sit.v.01'),
#   Synset('sit.v.02'),
#   Synset('sit_down.v.01'),
#   Synset('sit.v.04'),
#   Synset('model.v.03'),
#   Synset('ride.v.01'),
#   Synset('sit.v.07'),
#   Synset('baby-sit.v.02'),
#   Synset('seat.v.01'),
#   Synset('sit.v.10'),
#   Synset('seated.a.01'),
#   Synset('sitting.s.02')],
#  '45': [Synset('forty-five.s.01')],
#  'a': [Synset('angstrom.n.01'),
#   Synset('vitamin_a.n.01'),
#   Synset('deoxyadenosine_monophosphate.n.01'),
#   Synset('adenine.n.01'),
#   Synset('ampere.n.02'),
#   Synset('a.n.06'),
#   Synset('a.n.07')],
#  'fingers': [Synset('finger.n.01'),
#   Synset('finger.n.02'),
#   Synset('finger.n.03'),
#   Synset('finger.v.01'),
#   Synset('feel.v.09'),
#   Synset('finger.v.03'),
#   Synset('finger.v.04')],
#  'd': [Synset('vitamin_d.n.01'),
#   Synset('five_hundred.n.01'),
#   Synset('d.n.03'),
#   Synset('five_hundred.s.01')],
#  'lip': [Synset('lip.n.01'),
#   Synset('lip.n.02'),
#   Synset('sass.n.01'),
#   Synset('brim.n.01'),
#   Synset('lip.n.05')],
#  'excuse': [Synset('excuse.n.01'),
#   Synset('excuse.n.02'),
#   Synset('apology.n.03'),
#   Synset('excuse.v.01'),
#   Synset('excuse.v.02'),
#   Synset('excuse.v.03'),
#   Synset('apologize.v.02'),
#   Synset('excuse.v.05'),
#   Synset('excuse.v.06')],
#  'Hi': [Synset('hello.n.01'), Synset('hawaii.n.01')],
#  'come': [Synset('semen.n.01'),
#   Synset('come.v.01'),
#   Synset('arrive.v.01'),
#   Synset('come.v.03'),
#   Synset('come.v.04'),
#   Synset('come.v.05'),
#   Synset('come.v.06'),
#   Synset('issue_forth.v.01'),
#   Synset('hail.v.02'),
#   Synset('come.v.09'),
#   Synset('come.v.10'),
#   Synset('come.v.11'),
#   Synset('fall.v.04'),
#   Synset('come.v.13'),
#   Synset('total.v.01'),
#   Synset('come.v.15'),
#   Synset('come.v.16'),
#   Synset('occur.v.02'),
#   Synset('derive.v.05'),
#   Synset('do.v.04'),
#   Synset('come.v.20'),
#   Synset('come.v.21')],
#  'listening': [Synset('listening.n.01'),
#   Synset('listen.v.01'),
#   Synset('listen.v.02'),
#   Synset('heed.v.01')],
#  'gloves': [Synset('baseball_glove.n.01'),
#   Synset('glove.n.02'),
#   Synset('boxing_glove.n.01')],
#  'managing': [Synset('pull_off.v.03'),
#   Synset('manage.v.02'),
#   Synset('cope.v.01'),
#   Synset('oversee.v.01'),
#   Synset('wangle.v.01'),
#   Synset('do.v.11'),
#   Synset('wield.v.02')],
#  'sad': [Synset('sad.a.01'), Synset('sad.s.02'), Synset('deplorable.s.01')],
#  'forward': [Synset('forward.n.01'),
#   Synset('forward.n.02'),
#   Synset('forward.v.01'),
#   Synset('forward.a.01'),
#   Synset('forward.a.02'),
#   Synset('forward.a.03'),
#   Synset('advancing.s.01'),
#   Synset('forward.r.01'),
#   Synset('forth.r.02'),
#   Synset('ahead.r.02'),
#   Synset('ahead.r.03'),
#   Synset('fore.r.01')],
#  'hated': [Synset('hate.v.01'),
#   Synset('hat.v.01'),
#   Synset('hat.v.02'),
#   Synset('despised.s.01')],
#  'way': [Synset('manner.n.01'),
#   Synset('means.n.01'),
#   Synset('direction.n.01'),
#   Synset('way.n.04'),
#   Synset('way.n.05'),
#   Synset('way.n.06'),
#   Synset('way.n.07'),
#   Synset('room.n.02'),
#   Synset('way.n.09'),
#   Synset('way.n.10'),
#   Synset('way.n.11'),
#   Synset('way.n.12'),
#   Synset('way.r.01')],
#  'fans': [Synset('fan.n.01'),
#   Synset('sports_fan.n.01'),
#   Synset('fan.n.03'),
#   Synset('fan.v.01'),
#   Synset('fan.v.02'),
#   Synset('fan.v.03'),
#   Synset('winnow.v.01')],
#  'pointing': [Synset('indicate.v.02'),
#   Synset('orient.v.01'),
#   Synset('charge.v.17'),
#   Synset('steer.v.01'),
#   Synset('bespeak.v.01'),
#   Synset('luff.v.01'),
#   Synset('point.v.07'),
#   Synset('point.v.08'),
#   Synset('point.v.09'),
#   Synset('point.v.10'),
#   Synset('target.v.01'),
#   Synset('point.v.12'),
#   Synset('sharpen.v.07'),
#   Synset('point.v.14')],
#  'swallowed': [Synset('swallow.v.01'),
#   Synset('swallow.v.02'),
#   Synset('immerse.v.03'),
#   Synset('swallow.v.04'),
#   Synset('swallow.v.05'),
#   Synset('swallow.v.06'),
#   Synset('accept.v.07'),
#   Synset('swallow.v.08')],
#  'quietly': [Synset('softly.r.01'),
#   Synset('quietly.r.02'),
#   Synset('quietly.r.03'),
#   Synset('restfully.r.01')],
#  'spoiled': [Synset('botch.v.01'),
#   Synset('spoil.v.02'),
#   Synset('corrupt.v.04'),
#   Synset('pamper.v.01'),
#   Synset('thwart.v.01'),
#   Synset('itch.v.04'),
#   Synset('rape.v.02'),
#   Synset('mar.v.01'),
#   Synset('spoiled.s.01'),
#   Synset('bad.s.04')],
#  'ride': [Synset('drive.n.08'),
#   Synset('ride.n.02'),
#   Synset('ride.v.01'),
#   Synset('ride.v.02'),
#   Synset('ride.v.03'),
#   Synset('ride.v.04'),
#   Synset('tease.v.02'),
#   Synset('ride.v.06'),
#   Synset('drive.v.12'),
#   Synset('depend_on.v.01'),
#   Synset('ride.v.09'),
#   Synset('ride.v.10'),
#   Synset('ride.v.11'),
#   Synset('ride.v.12'),
#   Synset('ride.v.13'),
#   Synset('ride.v.14')],
#  'anxious': [Synset('anxious.s.01'), Synset('anxious.s.02')],
#  'captain': [Synset('captain.n.01'),
#   Synset('captain.n.02'),
#   Synset('captain.n.03'),
#   Synset('master.n.07'),
#   Synset('captain.n.05'),
#   Synset('captain.n.06'),
#   Synset('captain.n.07'),
#   Synset('captain.v.01')],
#  'stretched': [Synset('stretch.v.01'),
#   Synset('stretch.v.02'),
#   Synset('unfold.v.03'),
#   Synset('stretch.v.04'),
#   Synset('elongate.v.01'),
#   Synset('stretch.v.06'),
#   Synset('stretch.v.07'),
#   Synset('stretch.v.08'),
#   Synset('load.v.05'),
#   Synset('extend.v.17'),
#   Synset('stretch.v.11'),
#   Synset('stretched.s.01'),
#   Synset('stretched.s.02')],
#  'really': [Synset('truly.r.01'),
#   Synset('actually.r.01'),
#   Synset('in_truth.r.01'),
#   Synset('very.r.01')],
#  'why': [Synset('why.n.01')],
#  'intensely': [Synset('intensely.r.01')],
#  'Its': [Synset('information_technology.n.01')],
#  'settle': [Synset('settle.n.01'),
#   Synset('settle.v.01'),
#   Synset('decide.v.02'),
#   Synset('settle.v.03'),
#   Synset('settle.v.04'),
#   Synset('reconcile.v.03'),
#   Synset('sink.v.04'),
#   Synset('settle.v.07'),
#   Synset('settle.v.08'),
#   Synset('settle.v.09'),
#   Synset('settle.v.10'),
#   Synset('settle.v.11'),
#   Synset('settle.v.12'),
#   Synset('settle.v.13'),
#   Synset('settle.v.14'),
#   Synset('settle.v.15'),
#   Synset('settle.v.16'),
#   Synset('subside.v.03'),
#   Synset('ensconce.v.01'),
#   Synset('settle.v.19'),
#   Synset('finalize.v.01'),
#   Synset('settle.v.21'),
#   Synset('fall.v.32')],
#  'T': [Synset('thymine.n.01'),
#   Synset('deoxythymidine_monophosphate.n.01'),
#   Synset('metric_ton.n.01'),
#   Synset('t.n.04'),
#   Synset('triiodothyronine.n.01'),
#   Synset('thyroxine.n.01')],
#  'Please': [Synset('please.v.01'),
#   Synset('please.v.02'),
#   Synset('please.v.03'),
#   Synset('please.r.01')],
#  'grandchild': [Synset('grandchild.n.01')],
#  'close': [Synset('stopping_point.n.01'),
#   Synset('conclusion.n.08'),
#   Synset('finale.n.03'),
#   Synset('close.v.01'),
#   Synset('close.v.02'),
#   Synset('close_up.v.01'),
#   Synset('close.v.04'),
#   Synset('conclude.v.04'),
#   Synset('close.v.06'),
#   Synset('close.v.07'),
#   Synset('close.v.08'),
#   Synset('close.v.09'),
#   Synset('close.v.10'),
#   Synset('close.v.11'),
#   Synset('close.v.12'),
#   Synset('close.v.13'),
#   Synset('close.v.14'),
#   Synset('close.v.15'),
#   Synset('close_up.v.03'),
#   Synset('close.v.17'),
#   Synset('close.a.01'),
#   Synset('close.a.02'),
#   Synset('near.a.01'),
#   Synset('close.s.04'),
#   Synset('close.s.05'),
#   Synset('close.s.06'),
#   Synset('close.s.07'),
#   Synset('airless.s.01'),
#   Synset('close.s.09'),
#   Synset('close.s.10'),
#   Synset('close.s.11'),
#   Synset('close.s.12'),
#   Synset('close.s.13'),
#   Synset('cheeseparing.s.01'),
#   Synset('close.s.15'),
#   Synset('near.r.01'),
#   Synset('close.r.02')],
#  ...}

# %%
# %%time

# lda_similarities = []

# for N_FEATURES in N_FEATURES_LIST:
# tf_vectorizer = CountVectorizer(
#     max_features=N_FEATURES,
#     stop_words='english',
# )
# tf = tf_vectorizer.fit_transform(data_samples)
# tf_feature_names = tf_vectorizer.get_feature_names()

# for N_TOPICS in range(MIN_TOPICS, MAX_TOPICS + 1):
#     lda = LatentDirichletAllocation(
#         n_topics=N_TOPICS,
#         learning_method='online',
#         learning_offset=50.,
#         random_state=0,
#         n_jobs=4,
#     )
#     lda.fit(tf)
#     topics = get_topics(lda, tf_feature_names, N_TOP_WORDS)
#     similarities = [(word_list_similarity(topic), topic, len(topics)) for topic in topics]
#     lda_similarities.extend(similarities)

# lda_winners = sorted(lda_similarities, reverse=True)

# %%
with open('data/out/lda_winners.csv', 'w') as f:
    for topic in lda_winners:
        f.write('{}, {}, {}\n'.format(topic[0], ' '.join(topic[1]), topic[2]))

# %%
'{}, {}, {}'.format(topic[0], ' '.join(topic[1]), topic[2])
# Out:
# '0.6722436207494797, car drive seat road park driving bag drove home ride house window door inside hand bags head street taking pick, 191'

# %%
c=0
for i in range(1, 201):
    c+=i

# %%
c
# Out:
# 20100

# %%
topic
# Out:
# (0.67224362074947974,
#  ['car',
#   'drive',
#   'seat',
#   'road',
#   'park',
#   'driving',
#   'bag',
#   'drove',
#   'home',
#   'ride',
#   'house',
#   'window',
#   'door',
#   'inside',
#   'hand',
#   'bags',
#   'head',
#   'street',
#   'taking',
#   'pick'],
#  191)

# %%
print_topics(lda_winners[:10])
# Out:
# Topic #1:
# SIMILARITY: 0.672243620749 . Discovered topics: 191
# car drive seat road park driving bag drove home ride house window door inside hand bags head street taking pick
#
# Topic #2:
# SIMILARITY: 0.664257033619 . Discovered topics: 182
# car drive house seat road driving drove home ride window door inside street way lot park pick bag look pull
#
# Topic #3:
# SIMILARITY: 0.653545993766 . Discovered topics: 105
# car house door home drive seat road driving drove ride window inside way street stairs bags outside open walk bag
#
# Topic #4:
# SIMILARITY: 0.646932983514 . Discovered topics: 160
# team ball park dream game play line hit won running playing run ready fast air throw shot right pass set
#
# Topic #5:
# SIMILARITY: 0.641080358938 . Discovered topics: 157
# game play ball playing hit played beat won shot line ready air face throw middle fun threw like set high
#
# Topic #6:
# SIMILARITY: 0.640201534732 . Discovered topics: 80
# box picture bags stairs closet open bag shoes pack till pull door doors walk steps turn lights putting reach upstairs
#
# Topic #7:
# SIMILARITY: 0.638689521572 . Discovered topics: 200
# car house door home drive seat room window road driving stairs ride walk drove open going inside bed bags clothes
#
# Topic #8:
# SIMILARITY: 0.637439404356 . Discovered topics: 100
# car door bag seat window drive road open inside house way box driving home building ride hand outside minutes street
#
# Topic #9:
# SIMILARITY: 0.636974660368 . Discovered topics: 56
# room door open floor bed table small window wall hall voice inside doors chair stairs eyes hallway glass kitchen head
#
# Topic #10:
# SIMILARITY: 0.633820506908 . Discovered topics: 155
# says say asks looks ask smiles walks head nods hand pulls smile starts walk laughs takes turns look hands gets

# %% [markdown]
# #### NMF

# %%
from datetime import datetime

# %%
# %%time

tfidf_vectorizer = TfidfVectorizer(
    max_df=0.95,
    min_df=2,
    max_features=N_FEATURES,
    stop_words='english',
)
tfidf = tfidf_vectorizer.fit_transform(data_samples)
tfidf_feature_names = tfidf_vectorizer.get_feature_names()

nmf_similarities = []
for N_TOPICS in range(MIN_TOPICS, MAX_TOPICS + 1):
    nmf = NMF(
        n_components=N_TOPICS,
        random_state=1,
        alpha=.1,
        l1_ratio=.5,
    )
    nmf.fit(tfidf)
    topics = get_topics(nmf, tfidf_feature_names, N_TOP_WORDS)
    similarities = [(word_list_similarity(topic), topic, len(topics)) for topic in topics]
    nmf_similarities.extend(similarities)
    
    if N_TOPICS % 100 == 0:
        print(N_TOPICS, datetime.now())
    
nmf_winners = sorted(nmf_similarities, reverse=True)
# Out:
# 100 2017-06-12 18:35:34.841702
# 200 2017-06-13 16:37:50.501902
# CPU times: user 1d 6h 24min 54s, sys: 9h 53s, total: 1d 15h 25min 48s
# Wall time: 1d 4h 36min 37s

# %%
with open('data/out/nmf_winners.csv', 'w') as f:
    for topic in nmf_winners:
        f.write('{}, {}, {}\n'.format(topic[0], ' '.join(topic[1]), topic[2]))

# %%
print_topics(nmf_winners[:10])
# Out:
# Topic #1:
# SIMILARITY: 0.648428122943 . Discovered topics: 100
# look walk looks asks smile head smiles walks turn nod ask start hear say face hand nods starts grab turns
#
# Topic #2:
# SIMILARITY: 0.645495403787 . Discovered topics: 136
# look walk looks smile head asks smiles walks turn nod face ask start hear nods turns starts eyes grab looking
#
# Topic #3:
# SIMILARITY: 0.642188814187 . Discovered topics: 134
# black hair white blue red brown dark green shirt color wearing dress jeans pink light long purple grey blonde wear
#
# Topic #4:
# SIMILARITY: 0.640778642366 . Discovered topics: 104
# asks ask smiles nods nod laughs looks takes turns smile walks tell says pulls questions laugh question answer reply gets
#
# Topic #5:
# SIMILARITY: 0.640778642366 . Discovered topics: 172
# asks ask smiles looks nods nod laughs smile walks turns takes laugh pulls says tell question answer reply questions gets
#
# Topic #6:
# SIMILARITY: 0.639088471421 . Discovered topics: 186
# asks ask smiles nods looks nod laughs turns takes walks pulls says question questions reply answer laugh gets starts gives
#
# Topic #7:
# SIMILARITY: 0.63854016776 . Discovered topics: 91
# look walk looks smile head asks smiles turn walks nod face ask start eyes hear hand say nods starts turns
#
# Topic #8:
# SIMILARITY: 0.63854016776 . Discovered topics: 82
# look walk looks smile head asks smiles turn walks nod ask face hear start say hand eyes nods turns starts
#
# Topic #9:
# SIMILARITY: 0.636097544662 . Discovered topics: 166
# asks nod nods laughs says smile smiles reply laugh ask sigh tell takes pulls say roll shake turns smiling gives
#
# Topic #10:
# SIMILARITY: 0.636033689538 . Discovered topics: 163
# asks ask smiles looks nods smile nod laughs walks turns takes head laugh pulls says hand gets gives tell starts

# %% [markdown]
# ## Saving data

# %%
# stories_df.to_csv('data/out/werewolf_vampire_stories.csv', index=False)
